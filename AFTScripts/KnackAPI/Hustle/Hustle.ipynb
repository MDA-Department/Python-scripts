# %%
import os
import json
import csv
import pandas as pd
import math
import urllib.parse
from pathlib import Path


pd.set_option('display.max_columns', None)
INPUT_TABLE = 'Export_Full_Results_0000_part_00_combine.csv'
cache = {}

print(f'Reading from table: {INPUT_TABLE}')
df = pd.read_csv(INPUT_TABLE)

if False:
    print('Wrong')
else:
    print('Loaded table: '+INPUT_TABLE)

    print('Filling NaN...')
    df.fillna('', inplace = True)  
    print('Done with transformation')

    print('Resetting Index...')
    df = df.reset_index()
    print('Done with transformation')

    print('Starting iteration...')
    print('Current index: ')
    print('', end='\n')
    for index, row in df.iterrows():
        print(index, end='\r')
        
        org_id = row['organization_id']
        custom_fields = row['custom_fields']
        json_cf = json.loads(custom_fields)
        
        if org_id in cache:
            org_dict = cache[org_id]
        else:
            cache.update({org_id:{}})
            org_dict = cache[org_id]
            
        for k,v in json_cf.items():
            if k in org_dict:
                org_dict[k]+=1
            else:
                org_dict.update({k:0})

    print('', end='\n')
    print('Done iterating')
    print('=================')
    print(f'Added {len(cache)} custom field columns to table: \n{cache}')
# Out:
# Reading from table: Export_Full_Results_0000_part_00_combine.csv
# C:\Users\Sid\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (9,10,11,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Loaded table: Export_Full_Results_0000_part_00_combine.csv
# Filling NaN...
# Done with transformation
# Resetting Index...
# Done with transformation
# Starting iteration...
# Current index:
#
# 5012822
# Done iterating
# ...
# Added 122 custom field columns to table:
# ...

# %%
res = {'0LjPO12b3x': {'ZIP': 12635, 'Chapter': 11025, 'Affiliate': 6943, 'Leadership_Title': 133, 'City': 3451, 'State': 1562, 'NEA_ID': 105, 'Address': 3750, 'Member_ID': 111, 'custom_external_id': 105, 'Department': 3086, 'Member_Status': 6973, 'CD': 131, 'HD': 131, 'SD': 131, 'VAN_ID': 142, 'hotel': 55, 'Worksite': 427, 'recruiter': 97, 'College': 1915, 'Dues_Category': 7682, 'custom_extra_phone': 6961, 'custom_middle': 4259, 'custom_extra_email': 4598}, '0aY0aNnk97': {'Division': 4116, 'Worksite': 7519, 'Member_ID': 654, 'custom_external_id': 744, 'Chapter_Name': 4193, 'Council': 5864, 'Employer': 620, 'Member_Type': 4340, 'Occupation': 3356, 'Job_Title': 3969, 'HD': 2917, 'SD': 3157, 'City': 8201, 'Local_Name': 3380, 'Local_Number': 3554, 'HomeEmail': 2095, 'Street_Address': 1419, 'CellPhone': 1689, 'State': 3279, 'ZIP': 2828, 'leadership': 17, 'Organization': 5, 'CTUStrike_RSVP_101419': 4, 'VAN_ID': 506, 'CardLink': 256, 'cardtoken': 255, 'PartTime_FullTime': 222, 'MemberID': 185, 'unit': 354, 'Building': 2801, 'IL_State_House': 2591, 'Agent_last_name': 2553, 'IL_State_Senate': 2591, 'Agent_first_name': 2553, 'Agent_phone_number': 2552, 'IL_Congressional_District': 2591, 'Rank': 144, 'College': 144, 'Department': 144, 'CCCCV22pw': 1264, 'CCCCV22user': 1264, 'CCCSAV22pw': 361, 'CCCSAV22user': 361, 'Executive_Board': 35, 'Governing_Board': 29}, '0af10HH3E6': {'Zip': 2064, 'City': 2161, 'State': 2160, 'Address': 2160, 'Worksite': 2555, 'Job_class': 2459, 'Job_title': 1993, 'Member_ID': 2106, 'Payroll_ID': 1767, 'Dues_category': 2324, 'Member_status': 2937, 'Affiliate_Name': 1954, 'Secondary_Email': 2312, 'Worksite_Number': 1749, 'Affiliate_Number': 2034, 'Union_Initiation': 2318, 'Middle_Name': 1263, 'Affiliate_State': 206, 'DuesCategory': 21}, '0iwnZiPGBe': {'ZIP': 3921, 'City': 4247, 'State': 3921, 'Address': 4148, 'Division': 3283, 'Worksite': 3473, 'Recommitted': 3230, 'Member_Status': 3230, 'Recommit_Date': 2978, 'COPE': 1587, 'Ramsey_Co': 409, 'STP_Council': 409, 'Bldg_Steward_Code': 156}, '0jGOdBEi9B': {'ZIP': 9643, 'City': 9643, 'State': 16448, 'VAN_ID': 3001, 'Steward': 677, 'Employer': 9624, 'Worksite': 10897, 'Job_Class': 9018, 'Job_Title': 1650, 'Occupation': 9627, 'Street_Address': 3001, 'custom_external_id': 612, 'Date': 979, 'Division': 516, 'Member_ID': 465, 'Link': 0}, '0wuUrwPek8': {'Escuela': 6668, 'Municipio': 6668, 'Region_Escuela': 5352, 'Apellido_Materno': 7009, 'Estado': 3340, 'Apellido_Paterno': 3121, 'Zona': 463, 'Distrito': 463, 'Tipo_Delegado': 628, 'custom_external_id': 386, 'Worksite': 882, 'Local_Name': 882, 'Meeting_2_13': 105}, '1EBnUIIbou': {'COPE': 1147, 'FTPT': 1210, 'Campus': 1129, 'Member': 1147, 'Precinct': 1146, 'Recommit': 1147, 'FacultyID': 1147, 'Department': 1140, 'Member_Status': 1119, 'ActiveSemester': 1147, 'MemberFormOnFile': 1119, 'HardToFind': 70, 'DoNotCall': 394}, '1IRJCrH5ZK': {'Zip': 7586, 'City': 7588, 'State': 7587, 'Worksite': 912, 'Affiliate_Name': 832, 'Affiliate_State': 832, 'Affiliate_Number': 832, 'Address': 7438}, '2ewYXRewhT': {'ZIP': 14830, 'City': 14869, 'State': 14869, 'Address': 14871, 'Division': 5706, 'Worksite': 5899, 'Local_Name': 3154, 'Local_Number': 2606, 'Dues_Category': 5435, 'grade': 6562, 'School': 7060, 'Student_last_name': 6562, 'Student_first_name': 6562, 'Job_Title': 5113, 'custom_external_id': 5692, 'position': 449, 'secondary_phone': 1217, 'mobile_phone': 1568, 'Member_ID': 541, 'MI': 100, 'member_status': 295}, '3QDxi0ZtQt': {'Worksite': 8000, 'SD': 633, 'UBC': 527, 'UBR': 81, 'HD': 20, 'Job_Title': 1631, 'City': 107, 'Street_Address': 107, 'Job_Class': 158, 'Position': 35, 'Employer': 7, 'Survey_Results': 470, 'Occupation': 0}, '3WCdKZrAn4': {'ZIP': 645, 'City': 645, 'State': 646, 'Area': 380, 'COPE': 570, 'ZONE': 609, 'Member': 568, 'Employer': 619, 'JobClass': 559, 'Worksite': 638, 'HomePhone': 414, 'Job_Title': 419, 'Member_ID': 592, 'Dues_Category': 558, 'SecondaryEmail': 471, 'Street_Address': 640, 'District': 160, 'Leader_Status': 102, 'Division': 27}, '3h6DaeoyL2': {'ZIP': 1161, 'City': 1161, 'State': 1161, 'Address': 1161, 'Worksite': 1173, 'Job_Class': 977, 'Job_Title': 1085, 'Member_ID': 914, 'Department': 1168, 'Event_Name': 1213, 'Member_Status': 995, 'custom_external_id': 1590}, '3iYKUI1uQv': {'School_Board_District': 757, 'VANID': 3059}, '4RSXP1XASD': {'Zip': 249, 'City': 249, 'State': 249, 'Title': 303, 'EmplID': 258, 'Office': 206, 'Tenure': 304, 'Address': 249, 'College': 304, 'Department': 304, 'Work_Email': 258, 'MemberStatus': 257, 'Office_Phone': 203, 'Member_status': 258, 'Primary_Building': 243, 'Union_Contact': 86, 'Current_Assesment': 177, 'Union_Role': 12, 'Union_Role_2': 3}, '4TfH9QCDyg': {'Department': 2771, 'Employer': 824, 'Occupation': 691, 'custom_external_id': 1364, 'Campus': 1318, 'Membership': 1281}, '4bjbZUeyDO': {'Knack_ID': 755, 'Term_Status': 715, 'Assessment': 946, 'Occupation': 563, 'home': 365, 'Employer': 193, 'TU_Phone': 412}, '5NHdJ12tUJ': {'GUID': 198232, 'custom_external_id': 116830, 'Local': 61934, 'USCongress': 1559, 'Constituency': 960, 'WAStateHouse': 960, 'RecommitStatus': 961, 'AD': 669, 'SD': 669, 'Zip': 675, 'City': 675, 'State': 61630, 'VAN_ID': 669, 'Address': 675, 'Department': 5, 'MemberStatus': 122, 'AFT_member_ID': 60971, 'Work_Location': 5, 'Currently_Working': 5, 'State_Fed': 61089, 'COPE': 4}, '5drJchmKnQ': {'ZIP': 28378, 'City': 29372, 'GUID': 25988, 'State': 29250, 'County': 9523, 'Employer': 20857, 'Indiv_ID': 8960, 'Worksite': 15207, 'Job_Class': 19709, 'Job_Title': 12412, 'Member_ID': 18870, 'Member_TF': 5424, 'Department': 14479, 'Event_Name': 28303, 'Local_Name': 20720, 'Local_Number': 26491, 'Dues_Category': 7333, 'Street_Address': 24763, 'MI_House_District': 22316, 'Membership_Status': 13716, 'MI_Senate_District': 22474, 'custom_external_id': 18041, 'Congressional_District': 23527, 'Assessment': 10178, 'Endorsed_Candidate': 17271, 'Employer_ID': 4293, 'Custom_Reminder': 271, 'Email_Validation': 881}, '6D2EwI3f3Q': {'ZIP': 40759, 'City': 33000, 'State': 25884, 'Chapter': 18938, 'College': 51110, 'GNRC_ID': 35454, 'Renewed': 37446, 'NYSUT_ID': 25730, 'Job_Title': 38589, 'Department': 42123, 'Member_Status': 39350, 'Street_Address': 25634, 'Assessment': 4564, 'AD': 26070, 'SD': 15721, 'Senate_Name': 15721, 'Senate_Phone': 15721, 'Assembly_Name': 15721, 'Assembly_Phone': 15721, 'BP_Endorsement': 9231, 'Council_District': 9228, 'Council_Endorsement': 11149, 'fullname': 231, 'BklynControlGrp11_1': 565, 'BklynSolidarityGrp11_1': 565, 'College_PresName': 9318, 'Ventilation_Petition': 9318, 'Bus_Long': 1650, 'Bus_Short': 1650, 'BusAddress': 1650, 'BusLocation': 1650, 'Caravan_Borough': 113, 'Train': 2399, 'TravelTime': 2399, 'rallysite': 318, 'BCC_or_MEC': 318, 'Survey_Email': 12182, 'RSVP_Email': 1482}, '6rmh5iJ7UT': {'Campus': 7802, 'Building': 3683, 'Job_class': 6464, 'Department': 7607, 'Member_status': 8277, 'Zip': 7299, 'City': 7302, 'State': 7252, 'Dues_category': 2332, 'Pledge_Card': 1183, 'Strike_Vote': 1589, 'Address': 5823, 'Home_Phone_Rutgers': 1843, 'Cell_Phone': 1665, 'Home_Phone': 1215, 'Email_address': 348, 'Member_ID': 1377, 'CD': 65}, '6shaGVbpXd': {'Zip': 5141, 'City': 5141, 'State': 5142, 'Address': 5141, 'Home': 334, 'Work': 323, 'Worksite': 494, 'Apt': 65}, '9DHo0CXPvz': {'ZIP': 42701, 'City': 38464, 'State': 120303, 'Worksite': 28038, 'PCT': 7781, 'County': 8562, 'PCT_City': 7814, 'Web_Page': 1961, 'Candidate': 11802, 'Member_ID': 33685, 'PCT_Place': 7814, 'PCT_Location': 7814, 'Ballot_Number': 2333, 'UTD_Organizer': 32284, 'House_District': 2712, 'Street_Address': 31273, 'Employee_Number': 36389, 'WorkLocationName': 36153, 'custom_external_id': 13953, 'Region': 31409, 'House_Rep_phone': 8531, 'Early_Vote_Site': 264034}, 'BT9REu1uxP': {'Zip': 1290, 'City': 3681, 'GUID': 4016, 'Email': 1848, 'State': 3682, 'Address': 3682, 'MemberID': 1930, 'Worksite': 1312, 'Job_Class': 687, 'Accident_Ins': 726, 'CardMailDate': 586, 'MemberStatus': 4016, 'Dues_Category': 683, 'Liability_Ins': 726, 'AffiliateState': 683, 'Union_Init_Date': 561, 'custom_external_id': 683, 'EmployerID': 423}, 'CuFFpr5jKq': {'ZIP': 881, 'COPE': 838, 'City': 923, 'FT_PT': 759, 'State': 923, 'Address': 923, 'Worksite': 886, 'Department': 805, 'Member_Status': 818, 'Recommit_Status': 551}, 'DaqIjaPJD1': {'Unit': 5228, 'Zip': 1982, 'City': 1982, 'State': 1985, 'Address': 1984, 'COUNTRY': 1916, 'Phone_4': 2040, 'Member_Standing': 1044, 'Membership_Type': 1924, 'Primary_Affiliation': 1874, 'Phone_2': 1580, 'Phone_3': 53, 'Shift': 72, 'Building': 170, 'Job_class': 80, 'Assessment': 60, 'Member_ID': 204, 'Worksite': 26, 'Job_title': 26, 'Work_Area': 26, 'Dues_category': 192, 'Cell': 283}, 'DnSlSVC12G': {'Address': 841, 'Zip': 717, 'City': 717, 'State': 717, 'Worksite': 638, 'Job_class': 638}, 'E1NbxZ5Eea': {'EIN': 1617, 'Zip': 17805, 'City': 17792, 'State': 17790, 'Address': 17723, 'Job_Title': 11871, 'Work_Location': 5369, 'StateHouseRepName': 256, 'StateHouseRepPhone': 256, 'DWID': 2880, 'Turf': 1311, 'Work_Email': 4557, 'Open_Records_ID': 1311, 'custom_external_id': 2625, 'HD': 6207, 'SD': 6207}, 'E7leov5DaE': {'ZIP': 6119, 'City': 6409, 'State': 6253, 'Address': 6868, 'Employer': 5548, 'Worksite': 7233, 'Job_Title': 5782, 'Member_ID': 4673, 'Local_Number': 5363, 'Dues_Category': 4597, 'Member_Status': 5318, 'DWID': 3769, 'Division': 3663, 'Local_Name': 5640, 'Term_Status': 3663, 'LFT_Organizer': 1557, 'custom_external_id': 2956, 'BESE_PE19_Candidate': 2385, 'Chapter': 3096}, 'EO21f6sBmt': {'ZIP': 31556, 'State': 46421, 'VAN_ID': 5952, 'Member_ID': 26797, 'Local_Name': 7184, 'Local_Number': 28022, 'AffiliateName': 30786, 'custom_external_id': 3617, 'City': 30791, 'Address': 30679, 'Donors_Choose_Code': 164, 'GUID': 33362, 'County': 1531, 'Member_Code': 762, 'Member_Status': 22531, 'AffiliateState': 5642, 'Goal_Result': 43, 'Hutle_Groups': 67, 'APT': 23, 'Individual_ID': 12804, 'State_Fed': 5639, 'New_York': 17, 'Employer': 10700, 'Region': 4674, 'Occupation': 389, 'voterbase_id': 46, 'Dues_Category': 9213, 'StudentLoanScoreTS': 46, 'Leadership_Position': 15725, 'Worksite': 521, 'LocalRole': 4674, 'CD': 69, 'Org_Admin': 39, 'Group_Admin': 39, 'Hustle_Orgs': 39, 'AFT_PSRP': 4759, 'AFT_HigherEd': 4692, 'AFT_Teachers': 4692, 'AFT_PublicEmployees': 4692, 'AFT_NursesHealthProf': 4692, 'Executive_Council': 18, 'Union_Role': 41, 'Affiliate_Type': 2604, 'StateSenateDist': 725, 'AFT_K12': 1981, 'B2S_Signup_Link': 1}, 'EQlvZimVXv': {'ZIP': 2509, 'City': 2509, 'State': 2509, 'Address': 2828, 'Worksite': 2550, 'Job_Title': 300, 'Member_ID': 2897, 'Department': 2755, 'Term_Status': 300, 'Member_Status': 2857, 'custom_external_id': 1649, 'Dues_Category': 219, 'job_type': 2107, 'cluster': 2671, 'area_code': 0}, 'F6GnouwW1E': {'zip': 15814, 'City': 15922, 'Local': 13863, 'Shift': 8687, 'State': 15896, 'Status': 9619, 'HPAE_ID': 9605, 'Employer': 15072, 'Department': 14879, 'Local_name': 8031, 'Mailing_st': 15730, 'custom_external_id': 7964, 'Title': 11881, 'Supervisor': 33, 'Building': 2742, 'Occupation': 57, 'Cell_Phone': 2233, 'Target': 231, 'DOH': 1193, 'Officer_Title': 47, 'Campus': 3444, 'Mobile': 4568, 'member': 2849, 'Assessment': 1214, 'FB': 67}, 'FTc2pML01g': {'CAMPUS': 11672, 'position': 4102, 'mailing_address': 630, 'numberreferred': 72, 'UNIT_NAME': 7040, 'EMPLOYER': 2909, 'custom_external_id': 0}, 'Fg1xZoD4Cc': {}, 'FokcLkCLHN': {'KnackID': 904, 'employee_ID': 304, 'City': 2242, 'Job_Title': 2256, 'Supervisor': 1599, 'HomeDepartment': 2023, 'MembershipCard': 1262, 'Current_Assessment': 1584, 'Unit': 1407, 'State': 903, 'AuthCard': 1066, 'Member_ID': 5234, 'Occupation': 1192, 'Assessment_Date': 1389, 'StewardCouncil': 99, 'status': 134, 'ZIP': 218, 'Address': 218, 'Division': 232, 'Job_location': 218, 'OrganizingCommittee': 19, 'Local_Name': 4105}, 'GhRRx6C5BJ': {'Local_Number': 1599, 'WorkEmail': 0, 'LocalName': 8, 'Homephone': 47, 'Mobilephone': 16}, 'GiBSysHKD1': {'CD': 2759, 'LD': 3635, 'Local': 5166, 'Location': 2292, 'Position': 3103, 'Constituency': 2723, 'custom_external_id': 707, 'COPEDonor': 296, 'PayStep': 449, 'PayGrade': 738, 'Membership': 2066, 'AnnualSalary': 449, 'Attended': 1239, 'RecommitStatus': 563, 'Nickname': 640, 'Assessment_number': 15}, 'HQI0VK3FfZ': {'Title': 477, 'Job_Title': 390, 'Department': 482, 'Semester_Status': 458, 'Worksite': 39, 'Job_Class': 24}, 'HX7YrptvBU': {'ZIP': 31850, 'Area': 44384, 'City': 31850, 'State': 31846, 'Status': 40936, 'Chapter': 44379, 'Cluster': 39356, 'Job_Title': 34268, 'Member_ID': 38746, 'Employee_ID': 33867, 'Event_Value': 25733, 'Chapter_Code': 24932, 'Street_Address': 24388, 'custom_external_id': 33609, 'role': 2175, 'Staff': 43723, 'VAN_ID': 30492, 'Prop_15': 29630, 'Worker_ID': 29621, 'BOE_General': 29567, 'SBDistrict': 20848, 'Voted': 1977, 'Worksite': 671, 'Is_Itinerant': 3187, 'Recruited_By': 2862, 'Organization': 120, 'Employer': 42, 'Occupation': 0}, 'IHH5kzAJqk': {'GUID': 4139, 'School': 4359, 'custom_external_id': 2384, 'Member_or_NonMember': 4422, 'member': 481}, 'KhDWh9nsdJ': {'ZIP': 29068, 'City': 29079, 'State': 29084, 'Address': 29079, 'Indiv_ID': 3081, 'Worksite': 3146, 'Job_Class': 2858, 'Job_Title': 3015, 'Member_ID': 2954, 'Term_Status': 1844, 'Dues_Category': 3047, 'Member_Status': 2787, 'Affiliate_Name': 2217, 'Affiliate_Number': 2888, 'DWID': 1614, 'Unit': 2606, 'Employee_ID': 2408, 'Work_Location': 2410, 'Board': 91, 'Leader': 108, 'Steward': 91, 'Political': 39, 'Endorsement': 32, 'Sept_20_Meeting': 20, 'EBoard': 9, 'VAN_ID': 28941, 'Union_Relationship': 126}, 'KvK0aEef07': {'Zip': 7822, 'City': 7822, 'State': 7824, 'Address': 8121, 'Worksite': 2794, 'custom_external_id': 1138, 'Member_ID': 924, 'Phone_Number_2': 733, 'AFT_GUID': 415, 'billhwy_ID': 414, 'Middle_name': 1169, 'Job_title': 8, 'Job_class': 3}, 'Kx32ljgn2p': {'Employer': 11931, 'Local_Number': 12964, 'ZIP': 10646, 'City': 14610, 'OHHD': 7514, 'OHSD': 7516, 'State': 14493, 'VANID': 8728, 'Congressional_district': 11417, 'Address': 12119, 'Member_ID': 11728, 'Local_Name': 9210, 'Occupation': 939, 'Job_Title': 7453, 'Worksite': 3840, 'GUID': 11134, 'COPE_Status': 4662, 'Precinct': 2442, 'Vote_Status': 333, 'Neighborhood': 66, 'custom_external_id': 94, 'Buidingrep': 16, 'Officer': 7, 'PODleader': 14}, 'LTyIrIsoht': {'ZIP': 569, 'City': 569, 'State': 571, 'Address': 569, 'Worksite': 345, 'Job_Title': 341, 'Occupation': 472, 'Employer': 84}, 'LhVeyCwGRf': {'Chapter': 433, 'Employer': 440, 'CCP_Member': 12, 'UAP_Member': 188, 'Temple_Member': 51, 'Temple_Rating': 188, 'Arcadia_Member': 163, 'Arcadia_Rating': 24}, 'Ma2IYclxfG': {'NetID': 492, 'Employer': 373, 'Department': 1868, 'Occupation': 298, 'custom_external_id': 190}, 'MjLmdqTW4y': {'VANid': 1145, 'Middle_Name': 1053, 'Local_Number': 1149, 'Suffix': 108, 'WorkEmail': 0}, 'MpvYylzLll': {'Zip': 1650, 'City': 1650, 'State': 1650, 'Address': 1650, 'Member_ID': 1113, 'Dues_category': 1653, 'Member_status': 1722, 'Bargaining_Unit': 582, 'custom_external_id': 557}, 'NDHFMTZM2y': {'ZIP': 1445, 'City': 1500, 'State': 1500, 'Address': 1625, 'Worksite': 1493, 'Member_ID': 1570, 'Job_Class': 1435}, 'O00nHBVFGl': {'Zip': 5284, 'City': 5297, 'State': 5297, 'Area': 2771, 'GUID': 3339, 'Worksite': 3399, 'Job_Class': 3261, 'Job_Title': 3249, 'Work_Email': 3230, 'Employee_ID': 2854, 'Address_Line1': 3390, 'Dues_Category': 2700, 'Member_Status': 3074, 'Affiliate_Name': 2394, 'Affiliate_Number': 2394, 'COPE': 2522, 'payment_method': 2745, 'secondary_email': 1842, 'Address_Line2': 94, 'custom_external_id': 222, 'Home_Phone': 1453}, 'OV2Q9q7Blt': {'ZIP': 46582, 'City': 59114, 'State': 47471, 'Address': 47920, 'Worksite': 8012, 'Job_Class': 6254, 'Job_Title': 8048, 'LCTN_Code': 3845, 'Member_Code': 3501, 'Term_Status': 3612, 'Member_Status': 6870, 'District_Email': 7084, 'Hire_Date_Full': 3383, 'Leader_Code': 2399, 'Member_ID': 2446, 'Dues_Category': 43, 'Cohort_Year': 42, 'GPS_Program': 42, 'custom_external_id': 221, 'School_Board_District': 221, 'Age': 41341, 'Sex': 21}, 'Onnzl9wIjq': {'ZIP': 3783, 'City': 3794, 'State': 3790, 'Address': 3744, 'Worksite': 3073, 'Job_Title': 2809, 'Member_ID': 4792, 'Department': 5294, 'Citizenship': 3368, 'Employer_ID': 4851, 'Member_Status': 4712, 'custom_external_id': 3074, 'Term_Status': 3170, 'Event': 3002}, 'PoJXO7HrBg': {'City': 631, 'State': 631, 'Address': 631, 'ZIP': 355, 'Division': 229, 'Worksite': 229, 'Member_ID': 358, 'Local_Name': 229, 'Local_Number': 229, 'Dues_Category': 229, 'Job_Title': 1}, 'R6IYAS6ylk': {}, 'ROjs8aM2Cd': {'Campus': 8023, 'Unit': 6121, 'Member': 6059, 'Dept': 5471, 'AFTID': 2772, 'Assessment': 551, 'Quarter_Count': 773, 'Hire_Date': 408, 'Join_Date': 268, 'Title_Code': 53}, 'RUE7fpUJGf': {'Job_Class': 468, 'ZIP': 363, 'City': 363, 'State': 366, 'Address': 440, 'EMployer': 366, 'Worksite': 442, 'Fee_Payer': 366, 'Job_Title': 506, 'Member_ID': 366, 'Work_Unit': 308, 'Dues_Category': 451, 'Member_Status': 255, 'Department': 294, 'Work_Email': 46, 'Local_Number': 773, 'PhoneSource': 45, 'custom_external_id': 32, 'Agency': 84}, 'RfVXC5yLhr': {'VAN_ID': 91189, 'Zip': 8033, 'City': 8033, 'GUID': 8482, 'Race': 8245, 'dwid': 8268, 'Gender': 8245, 'Division': 7875, 'State_Fed': 10823, 'Home_State': 83120, 'Voted_Status': 10460, 'Member_Status': 8259, 'AFT_Vote_Status': 7638, 'Affiliate_State': 79771, 'Affiliate_Number': 79155, 'Previously_On_GOTV_Hustle': 7638, 'LAN_MemberType': 2655, 'Affiliate_Name': 77477, 'aftvotes_state_page': 66860, 'state_elections_site': 77492, 'candidate_for_persuasion2': 77492, 'CD': 4835, 'Script': 27, 'Home_City': 27, 'source_list': 27, 'custom_external_id': 1505, 'ballot_tracker_link': 67, 'Address': 0}, 'S96Z35fTKp': {'Local_Number': 325}, 'SAYme4HAJt': {'Employer': 1202, 'Occupation': 810, 'custom_external_id': 1251, 'Zip': 3324, 'City': 3324, 'DWID': 1006, 'State': 3324, 'AffiliateNumber': 1181, 'VANID': 3069, 'County': 3069, 'Address': 3267, 'Local_Union': 979, 'House_District': 1391, 'Senate_District': 1391, 'Preferred_Number': 1312, 'Congressional_District': 1391, 'MemberStatus': 1648, 'Leader': 272, 'Worksite': 1169, 'GUID': 898, 'Unit': 898, 'Building_Reps': 1, 'Charter': 29, 'Officer': 31}, 'T2cu8fpreJ': {'ZIP': 1071, 'City': 1070, 'FLSA': 1355, 'PERNR': 1069, 'State': 1070, 'Worksite': 1069, 'Job_Title': 1068, 'Occupation': 234, 'Street_Address': 1070, 'COPE': 342, 'Employer': 22}, 'TaG74sm1uw': {'Address': 6370, 'BR': 769, 'Worksite': 1496, 'Commitment': 1115, 'PaymentMethod': 1411, 'JobTitle': 1353, 'Member': 883, 'Failed': 33}, 'UHq7mUkZBr': {'Zip': 697, 'City': 698, 'State': 1237, 'Worksite': 807, 'Department': 1473, 'Discipline': 1214, 'LastRating': 1329, 'VoteYesPlan': 730, 'VotePlanDate': 778, 'Away_Eligible': 778, 'AuthCardSigned': 1327, 'LastRatingDate': 710, 'Voting_Location': 781, 'GOTV_Target_List': 732, 'GOTV_Targets_Final': 732, 'custom_external_id': 886, 'GOTV_Targets_Backup': 732, 'VoteYesPledgeSigned': 781, 'source_phone': 605, 'Address': 113, 'HowVoted': 231, 'VotingWithGroup': 171, 'Missed_Vote_Plan': 130}, 'UZweGiuIaU': {'State': 86, 'Gender': 50, 'Birthday': 50, 'Employer': 74, 'Job_Desc': 51, 'Worksite': 65, 'Job_Class': 50, 'Work_email': 50, 'Years_Dist': 50, 'Middle_Name': 59, 'Total_Years': 50, 'Affiliate_Name': 80, 'Affiliate_Number': 80, 'custom_external_id': 65, 'Custom_ID': 16}, 'VI9hWOEDAq': {'ZIP': 84569, 'City': 84571, 'State': 84431, 'Address': 82300, 'Worksite': 7775, 'GUID': 12135, 'County': 8832, 'Region': 17965, 'KnackID': 10982, 'District': 58280, 'PaymentMethod': 11379, 'BillHwyID': 8995, 'work_email': 10233, 'custom_external_id': 8082, 'Address_2': 832, 'COPE': 5114, 'Member_ID': 2943, 'TxHouseDistrict': 686, 'personal_email': 11019, 'Date': 12020, 'Dues_Category': 3593, 'Job_Class': 1512, 'Gender': 23116, 'Certificate_Number': 22959, 'Cert_Exp_Date': 11395, 'Job_Title': 5067, 'Middle': 15539, 'Reason': 42}, 'VYLjfcemzt': {'ZIP': 2426, 'City': 2453, 'State': 2379, 'Address': 2453, 'Worksite': 842, 'Job_Title': 256, 'BH_ID': 72, 'BH_Date': 74, 'Bill_Highway': 74, 'Dues_Category': 152, 'Building_Rep': 6, 'Member_ID': 138}, 'Vhr9W9EhxN': {'Title': 5001, 'Campus': 4947, 'Zipcode': 2982, 'Building': 4946, 'Home_city': 3636, 'Department': 5001, 'State_LD': 2355, 'Hire_Date': 3462, 'Membership': 3373, 'work_email': 3462, 'Campus_phone': 3462, 'Seniority_date': 3462, 'self_ID_gender': 3385, 'Member_since': 3034, 'FLSA_status': 3105, 'mental_health_event_invite': 2042}, 'Vl9UgRzzCc': {'DWID': 27117, 'State': 100972, 'vanid': 27173, 'state_fed': 810633, 'Local_Union': 831900, 'aft_cdb_guid': 834918, 'DOE_Survey_Outreach_Attempt': 26514, 'Email': 631062, 'Local_Number': 29378, 'Member_status': 614414, 'RichardFordID': 21927, 'Summer_Token_Link': 827028, 'MemberID': 577761, 'Member_ID': 232416, 'Source': 7737, 'script': 17648, 'Zip': 35525, 'City': 35684, 'Address': 35777, 'division': 160792, 'Affiliate_State': 480489, 'localnbr': 347203, 'local_followup_contact': 780420, 'Employer': 11930, 'upload_date': 512, 'affiliate_acronym': 188, 'local_id': 12998, 'FFEL': 34, 'Full_Time': 56, 'Loan_Status': 54, 'Private_Loan': 16, 'Loan_Servicer': 56, 'Repayment_Plan': 54, 'Gov_NP_Employee': 56, 'Federal_Direct_Loan': 46, 'Parent_Plus': 7, 'Worksite': 1091}, 'YMFh2F6CSd': {'Department': 1079, 'Campus': 919, 'Bargaining_Unit': 968, 'BU': 727, 'Current_Member': 465, 'Priorities_Card': 779, 'Member_Card_Completed': 23, 'Worksite': 472, 'Job_Title': 417, 'Follow_Up': 36, 'Organizer': 106, 'AFT_workunit': 203, 'SD': 29}, 'YUcR1vCF2I': {'Date': 3378, 'Arena': 950, 'Shift': 5130, 'Employer': 7226, 'Sumac_ID': 3631, 'Worksite': 7367, 'Job_Title': 4805, 'Member_ID': 4981, 'Department': 5995, 'Occupation': 5318, 'Employee_ID': 4937, 'alt_phone_1': 326, 'Member_Status': 3653, 'Bargaining_Unit': 5864, 'The_Real_Sumac_ID': 4895, 'Room': 318, 'Time': 403, 'Organizer': 3122, 'target522': 669, 'paper_survey': 2177, 'Preferred_name': 796, 'Position': 2502, 'Survey_URL': 1779, 'PIN': 208, 'Call_in_Number': 208, 'custom_external_id': 323, 'reg_status': 258, 'party': 278, 'Plus_One': 142, 'organizer_department': 73, 'alt_phone_2': 17}, 'a3wUFrT4xo': {'CD': 5964, 'HD': 5963, 'SD': 5964, 'ZIP': 9217, 'City': 11783, 'DWID': 5646, 'State': 10907, 'County': 9216, 'Member': 9952, 'Address': 11783, 'Worksite': 7577, 'Job_Class': 7335, 'Member_ID': 7127, 'Local_Name': 7634, 'Chapter_Name': 6889, 'Local_Number': 6889, 'AFT_Job_Class': 6629, 'Dues_Category': 7128, 'Member_Status': 7963, 'primary_email': 5994, 'second_email': 609}, 'bqHARUfq5Z': {'shift': 14528, 'Department': 18723, 'member_type': 16484, 'BU': 10908, 'custom_external_id': 3741, 'Mobile_Phone': 2666, 'membership': 153, 'Membership_Status': 5337, 'address': 7596, 'Facility': 10476, 'Organizer': 164, 'Hustle62520': 5, 'State': 1}, 'djMU5cP2fO': {'ZIP': 2094, 'City': 2094, 'Unit': 2151, 'AK_ID': 2137, 'State': 2094, 'Employer': 2094, 'BU_Status': 2024, 'Member_ID': 1768, 'Member_Status': 2141, 'House_District': 544, 'Street_Address': 2094, 'Bargaining_Unit': 1219, 'Senate_District': 544, 'BA_Status': 213, 'EIB_Balance': 486, 'Occupation': 32, 'Shift': 647, 'Sex': 82, 'Party': 82, 'VAN_ID': 82, 'Middle_Name': 80, 'Suffix': 0}, 'e46EHrKsIR': {'Zip': 134, 'City': 189, 'State': 190, 'Address': 185, 'Job_class': 326, 'Worksite': 5}, 'eFSoKcA59F': {'Zip': 8283, 'City': 9397, 'DWID': 8394, 'GROUP': 8388, 'VANID': 10754, 'Address': 10974, 'HomeState': 7348, 'AffiliateState': 8131, 'Affiliate_Name': 8388, 'Assessment_Nbr': 968, 'Affiliate_Number': 8513, 'custom_external_id': 8152, 'Work_Email': 8103, 'Unregistered__Public': 387, 'GOTV_Public': 462, 'AffiliateNumber': 322}, 'eutWq0Ccdn': {'zip': 765, 'GUID': 693, 'city': 772, 'state': 773, 'address': 772, 'worksite': 725, 'job_class': 766, 'local_name': 462, 'middle_name': 329, 'local_number': 412, 'custom_external_id': 530, 'department': 537, 'address_2': 31, 'Employer': 537, 'work_unit': 404}, 'fpgEJMGqq1': {'ZIP': 16233, 'City': 17248, 'State': 16090, 'Address': 16109, 'Division': 15557, 'Local_Name': 18581, 'Local_Number': 17975, 'Campaign': 1952, 'Worksite': 5649, 'Job_Title': 3880, 'Dues_Category': 10098, 'Member_ID': 10417, 'DWID': 10328, 'Member_Status': 530, 'Unit': 1504, 'KnackID': 266, 'WorkUnit': 266, 'LastRating': 372, 'MissionStatement': 266, 'GUID': 578}, 'gFisdJpdKd': {'Extra': 2555, 'Employer': 4279, 'Worksite': 4187, 'Job_Title': 2436, 'Cell_Phone': 3981, 'Head_Phone': 2766, 'Work_Phone': 777, 'extra_extra': 3504, 'Member_Status': 4301, 'Work_location': 2762, 'emergency_phone': 2453, 'preferred_phone': 3919, 'Member_Classification': 2609, 'Occupation_description': 4267, 'Home_Phone': 2504, 'ZIP': 1624, 'City': 1614, 'Van_ID': 105, 'Work_Email': 483, 'parish': 110, 'Years_In_System': 313, 'State': 1352, 'Address': 1355, 'Member_ID': 186, 'State_Leg_District': 15, 'Participation': 203, 'Personal_Email': 918, 'District_They_Live_In': 259, 'school_board': 405, 'Voter_File_Address_2022': 344}, 'hsFrKJK6ga': {'Zip': 2232, 'City': 1801, 'Name': 1759, 'UNIT': 1070, 'Local': 2777, 'State': 1158, 'Phone2': 172, 'Address': 2702, 'CHAPTER': 1069, 'Employer': 1069, 'LOCATION': 1233, 'LocalName': 1662, 'APEA_Region': 1070, 'Description': 1677, 'Employer_Zip': 866, 'Employer_City': 907, 'MemberAddress': 1659, 'Employer_State': 888, 'Employer_Address': 883, 'MiddleName': 1291, 'JOB_DESCRIPTION': 963, 'custom_external_id': 43, 'JOB_DEPT': 711, 'Job_class': 25, 'Middle_Initial': 828, 'Job_title': 62}, 'i4AVYeuomj': {'CD': 15241, 'HD': 15236, 'ZIP': 16614, 'City': 16452, 'State': 16433, 'VAN_ID': 11609, 'Local_Name': 15059, 'Street_Address': 16206, 'SD': 1950, 'NEA_ID': 9344, 'Member_ID': 8623, 'Local_Number': 5741, 'Employer': 1606, 'custom_external_id': 398, 'Worksite': 1310, 'Position': 1297, 'Home_Phone': 9672, 'Membership_Type': 1392, 'Chapter': 707, 'Occupation': 634, 'Middle_Name': 2436}, 'iBvy8nwKc9': {'custom_external_id': 4586, 'ZIP': 4922, 'Worksite': 3861, 'Job_Class': 4921, 'Job_Title': 4921, 'Member_Status': 4922}, 'jOep5R2X9l': {'Date': 2382, 'Address': 1564, 'Department': 2093, 'MemberStatus': 763, 'Zip': 2291, 'City': 2268, 'Campus': 1468, 'JobCode': 1675, 'G_Number': 2200, 'HireDate': 2165, 'Employee_Group': 2271, 'Time': 1436, 'custom_external_id': 263, 'strike_and_win': 629}, 'jefCLIdoF0': {'ZIP': 17860, 'City': 17148, 'State': 17056, 'Worksite': 16323, 'Job_Title': 12742, 'Member_ID': 11749, 'Street_Address': 16565, 'Worksite_Number': 15229, 'custom_external_id': 12972, 'Region': 10731, 'VAN_ID': 11741, 'Position_Code': 10310, 'Region_Coordinator': 116, 'home_phone': 961, 'member_status': 2965, 'state_house_district': 950, 'DWID': 7015, 'Employer': 1, 'Occupation': 1}, 'jlpNJlKdkQ': {'custom_external_id': 30361, 'new_hire': 58, 'token': 8264, 'voting2022': 8264, 'voting2022part2': 17604, 'BOEID': 1666, 'FieldRep': 1710, 'Worksite': 3820, 'Ward': 382, 'NUMBER': 269}, 'kfuZiLwPaQ': {'ZIP': 917, 'City': 919, 'Shift': 866, 'State': 919, 'Worksite': 1261, 'Job_Title': 1302, 'Work_Unit': 755, 'Department': 1287, 'Local_Name': 1280, 'Local_Number': 1207, 'Mobile_Phone': 408, 'Dues_Category': 1299, 'Street_Address': 875, 'custom_external_id': 377, 'FTE': 1053, 'Member_ID': 50}, 'liaEtikTVp': {'ZIP': 75807, 'City': 70394, 'Term': 4703, 'State': 69946, 'Address': 71198, 'Worksite': 41533, 'Member_Status': 113161, 'GUID': 99031, 'Indiv_ID': 72332, 'Full_Time': 11129, 'Join_Date': 2727, 'Member_ID': 102191, 'Department': 19601, 'Local_Name': 108258, 'Term_Status': 6947, 'Local_Number': 108311, 'Dues_Category': 70353, 'custom_external_id': 3766, 'CD': 35636, 'HD': 34645, 'SD': 35034, 'DWID': 34090, 'VAN_ID': 35582, 'Local_Acronym': 34533, 'Home_Phone': 6153, 'Fee_Payer': 5312, 'Occupation': 960, 'FT_PT': 31460, 'personal_email': 10883, 'bargaining_unit': 2930, 'FTE': 1706, 'Job_Title': 22215, 'seniority': 146, 'Months_Worked': 146, 'Employer': 2890, 'Start_Date': 3962, 'Mobile_Phone': 76, 'job_class': 5418, 'Job_Code': 4827, 'Hire_Date': 2678, 'COPE': 5858, 'Group': 31866, 'Grade': 732, 'Site_Rep': 134, 'Secondary': 543, 'Elementary': 1246, 'Work_Email': 3613, 'Middle_Name': 3514, 'Recommit': 2629, 'Loan_Servicer': 170, 'Student_Debt_Clinic': 241, 'Leadership_position': 938, 'Work_Hours': 860, 'Part_Time': 10475, 'Cell_number': 346, 'UC_ID': 3681, 'ZIP4': 996, 'GENDER': 394, 'zip_last_four': 362, 'Work_Phone': 1939, 'Work_Extension': 101, 'PollDescription': 309, 'Currently_Working': 3460, 'Suffix': 14, 'SDC': 79, 'LAMC_Barg': 161, 'Potential_Member': 232, 'Language': 5}, 'ljWHFrKDL3': {'G_number': 180, 'Job_title': 180, 'Department': 180, 'Zip_address': 179, 'City_address': 179, 'State_address': 179, 'Campus_address': 180, 'Street_Address': 179, 'Member_status': 11, 'Campus': 9, 'tag': 19}, 'loe0Lk9RKJ': {'Key': 982, 'ZIP': 863, 'Area': 972, 'City': 893, 'State': 861, 'Address': 869, 'Acad_Dept': 1045, 'Member_ID': 1144, 'Hiring_Dept': 1096, 'Member_Status': 1374, 'Quarter_Status': 398, 'Union_Role_AY20_21': 89, 'Pronouns': 525, 'Citizen': 925, 'Union_Role_AY21_22': 82}, 'nEmLLuu2FE': {'Job_Title': 156}, 'oC6uqzf9dF': {'Turf': 2727, 'unit': 5319, 'State': 4398, 'Worksite': 2270, 'Last_Rating': 1798, 'Address': 3638, 'City': 3805, 'Job_Class': 2963, 'Job_Title': 2885, 'Member_Status': 1429, 'home_phone': 152, 'KNACK_ID': 1405, 'BTeam_Cluster': 1440, 'UVM_Department': 920}, 'oZjGGBtdnR': {'City': 38037, 'Zone': 15605, 'VAN_ID': 23153, 'Address': 32460, 'Employer': 6745, 'HFT_Member': 15319, 'Occupation': 15962, 'Postal_Code': 18317, 'AFT_Division': 5561, 'HISD_employID': 8645, 'Worksite_Name': 19033, 'HFTRecordNumber': 7641, 'StateHouseRepName': 2435, 'Alt_Deduction_Form': 13880, 'custom_external_id': 5205, 'StateHouseRep_phone': 2423, 'Personal_Email': 4093, 'CD': 34620, 'HD': 36712, 'SD': 37643, 'Cope_Contribution': 1329, 'Pct': 3343, 'HFT_VY_Assessment': 2326, 'HESP_Member': 158, 'Day1_Session1': 37, 'Day1_Session2': 37, 'Day2_Session1': 37, 'Day2_Session2': 37, 'Polling_Address': 283, 'Polling_Location': 283, 'Also_Needs_2_Vote': 150, 'Home_Home_number': 95}, 'ocl0FU17Fv': {'ZIP': 1834, 'City': 1835, 'DWID': 1809, 'State': 1855, 'Address': 1854, 'Division': 1837, 'Worksite': 1127, 'Member_ID': 1856, 'Local_Name': 1837, 'Local_Number': 1837, 'Dues_Category': 1836, 'Job_Title': 647, 'custom_external_id': 900, 'Fee_Payer': 44}, 'orIeOZq4Cx': {}, 'pGA2ALWC4c': {'Local_Number': 626, 'ZIP': 250, 'City': 250, 'State': 250, 'Agency': 240, 'Address': 250, 'Worksite': 289, 'Job_Title': 255, 'Member_ID': 239, 'Local_Name': 240, 'Dues_Category': 289, 'WorkEmail': 13, 'custom_external_id': 2}, 'pdPEL6vS8l': {'KNACK_ID': 1585, 'Worksite': 2744, 'Member_Status': 3712, 'ZIP': 2454, 'City': 2624, 'State': 2623, 'Local_Name': 2325, 'Local_Number': 2241, 'Street_Address': 2607, 'Member_ID': 2017, 'custom_external_id': 301, 'Job_Title': 1922, 'Department': 375, 'Employment_status': 82, 'ID': 426, 'Home_Org': 423, 'position': 730, 'RATE': 306, 'Start_Date': 485, 'Work_Email': 220, 'Middle_Name': 170, 'GMM_Location': 73}, 'qstkabuQ7Y': {'GUID': 9149, 'Member_Status': 9149, 'tth_010820_invite': 9149, 'Worksite': 271, 'Job_Class': 271, 'Job_Title': 259, 'Dues_Category': 272, 'custom_external_id': 19, 'Local_Name': 7, 'Local_Number': 7}, 'rEbBwYBSg3': {'email1': 6340, 'email2': 2583, 'email3': 1348, 'Zip': 9133, 'Address': 9066, 'HomeCity': 9133, 'HomeState': 9133, 'job_title': 9186, 'Assessment': 10462, 'Department': 9199, 'employeeid': 9111, 'job_status': 8949, 'Card_Signed': 8981, 'Last_Rating': 10649, 'comp_frequency': 8955, 'Affiliate_State': 7414, 'FTE': 5305, 'verified': 2180, 'KnackID': 7255, 'Union_Relationship': 5642, 'Last_Rating_Date': 3876, 'GOTV_Target': 7348, 'Excelsior_List': 7348}, 'rlIrKW4TxN': {'Worksite': 4341, 'ZIP': 1464, 'City': 1464, 'State': 1464, 'Address': 1464, 'Dues_Category': 177, 'Member_ID': 1831, 'Job_Title': 226}, 'sHihkvJkFi': {'City': 1450, 'Dept': 2385, 'FT_PT': 1273, 'State': 1450, 'Active': 1153, 'Campus': 2336, 'Address': 1450, 'Zip_Code': 1272, 'MembershipStatus': 1374, 'custom_external_id': 1699, 'EMPID': 2219, 'Status': 2154}, 'sY9FEhKO9r': {'ZIP': 6730, 'City': 3677, 'Address': 3681, 'Worksite': 6988, 'Job_Class': 6836, 'Member_ID': 6517, 'Dues_Category': 3056, 'State': 3643, 'Member_Status': 6941, 'work_email': 1728, 'EmplID': 568, 'School': 6492, 'Job_Title': 262, 'WARD': 55, 'Years_Service': 30, 'GUID': 6787}, 'ssScXc61uZ': {'ZIP': 389, 'City': 389, 'Address': 389, 'Worksite': 383, 'Member_ID': 383, 'State': 13}, 'szgSZcGFU7': {'ZIP': 1417, 'City': 1530, 'State': 1417, 'Address': 1540, 'Worksite': 1286, 'Job_Class': 953, 'Job_Title': 1051, 'Member_ID': 1246, 'Work_Unit': 1252, 'Member_Status': 1332, 'LocalNbr': 135, 'PollingLocation': 660, 'custom_external_id': 169}, 'taM4iIt1Qt': {'ZIP': 7581, 'City': 7616, 'Unit': 5560, 'Local': 3360, 'State': 7614, 'Division': 1955, 'Local_Name': 6328, 'Local_Number': 7713, 'Street_Address': 3852, 'legislator_name': 351, 'legislator_number': 351, 'Action_Link': 499, 'State_Senator': 499, 'Senate_District': 567, 'Member_ID': 5557, 'Date_entered': 23, 'GUID': 7450, 'MemberStatus': 7450, 'Agency': 176, 'Worksite': 39, 'Bldg_ldrship': 135, 'custom_external_id': 131, 'activist': 11, 'Late_shift': 5}, 'uNTuh3TMr7': {'Member_ID': 106436, 'Occupation': 39369, 'Member_Status': 142959, 'CD': 152931, 'HD': 152950, 'SD': 150731, 'ZIP': 231772, 'City': 254329, 'DWID': 119800, 'NEA_ID': 95471, 'Address': 246816, 'UniSERV': 113281, 'Division': 71233, 'Worksite': 197312, 'Job_Title': 120411, 'Local_Name': 123454, 'Chapter_Name': 82946, 'Local_County': 59119, 'Local_Number': 75863, 'Member_Number': 79676, 'custom_external_id': 84576, 'COUNTY': 148746, 'STATE': 92754, 'VAN_ID': 82095, 'Employer': 79939, 'Building_Rep': 2836, 'Voting_Location': 12474, 'Legislator_Name': 11294, 'Legislator_phone': 11295, 'Deduction_Code': 4458, 'Upload_date': 75518, 'Unit': 81300, 'New_Ed': 2092, 'Year_of_Birth': 81962, 'DOH': 16619, 'Gender': 97138, 'Ethnicity': 45682, 'AltPhone': 23773, 'FYRE': 14112, 'Term_Status': 6329, 'State': 170577, 'District': 4942, 'PAC': 577, 'DC_Code': 668, 'FL_SEA_Name': 1249, 'Local_State': 4145, 'SB_District': 6618, 'voter_status': 2459, 'uniqueID': 6370, 'Join_Date': 2182, 'Group': 2723, 'NEA_VAN_ID': 22117, 'Job_Class': 1973, 'Affiliate_Area': 3533, 'home_email': 56020, 'VMB_Status': 9633, 'Earlyvote_hours': 2160, 'Early_vote_location': 2160, 'Earlyvote_polladdress': 2160, 'Votinglocation_address': 1821, 'Earlyvote_location': 929, 'GREAT': 35}, 'v8m5vK1Bkg': {'FTE': 23850, 'ZIP': 23587, 'City': 23589, 'Shift': 22243, 'State': 23825, 'Address': 20189, 'Worksite': 23229, 'Job_Class': 2157, 'Member_ID': 19180, 'Department': 22343, 'Upload_Date': 22562, 'Member_Status': 19484, 'Affiliate_Name': 16135, 'Address_Street_2': 5038, 'Affiliate_Number': 17136, 'Title': 1047, 'Union': 5776, 'custom_external_id': 1298, 'Dues_Category': 94, 'home_phone': 8884, 'Hire_Date': 1336, 'Job_Title': 617, 'Name': 16100, 'Info_Picket': 10, 'Picket_Pledge': 57}, 'w0q2ERfa5z': {'ZIP': 13454, 'City': 12257, 'State': 12257, 'Emp_ID': 12128, 'Region': 32444, 'Address': 12649, 'Agency_Name': 13297, 'Division_Name': 12557, 'International': 12128, 'Member_Status': 12147, 'Division_Number': 26510, 'custom_external_id': 35}, 'w3fh6pn5fa': {'Worksite': 3929, 'Job_class': 4030, 'Member_Status': 9686, 'Member_ID': 157, 'Dues_category': 3}, 'wBngGwzdS5': {'City': 311664, 'SAISD_District': 18196, 'SAISD_Candidate': 14403, 'State_Abbreviation': 162411, 'GUID': 15760, 'local': 60075, 'Worksite': 69324, 'Zip_Code': 162087, 'local_name': 14223, 'Member_Status': 20995, 'Membership_ID': 28006, 'personal_email': 8383, 'Street_Address1': 154499, 'custom_external_id': 73529, 'Email2': 9132, 'Street_Address2': 4920, 'Party': 12762, 'Candidate': 6761, 'District': 147699, 'AMP_Region': 13747, 'EMPLOYER': 49180, 'sex': 76364, 'Turf': 15092, 'Constituent_Type': 1925, 'School_Employee_Type': 2558, 'Role_Name': 3955, 'District_Email': 3921, 'Highest_Degree': 333, 'Current_Hire_Date': 3955}, 'wiag1iegvo': {'Campus': 302, 'Employer': 207, 'Home_phone': 120, 'work_email': 200, 'PaymentMethod': 259, 'Occupation': 0}, 'x29Hvx6DyP': {'school': 569, 'custom_external_id': 297, 'level': 370, 'region': 377}, 'x7oGJSYzIr': {'City': 133, 'Zip': 58, 'State': 58, 'Address': 58, 'PCT': 46, 'PCT_Address': 46, 'custom_external_id': 46}, 'xLBC0bsqGB': {'ZIP': 0, 'City': 0, 'State': 0, 'Address': 0}, 'yfMWOoOMce': {'ZIP': 4810, 'City': 4817, 'RN_APRN': 4530, 'District': 4830, 'Employer': 3946, 'Job_Type': 3632, 'Local_Name': 4985, 'Occupation': 3944, 'Member_Status': 4902, 'Street_Address': 4832, 'custom_external_id': 1607}, 'yvsWk5Galq': {'ZIP': 14637, 'City': 17674, 'DWID': 3215, 'State': 17415, 'Address': 17733, 'Division': 6108, 'Job_Title': 5421, 'Member_ID': 10961, 'Local_Name': 7664, 'Local_Number': 13856, 'Dues_Category': 3404, 'Member_Status': 10174, 'Work_Email': 1603, 'Worksite': 6818, 'JobCode': 1455, 'Job_Class': 1539, 'Bargaining_Unit': 2765, 'custom_external_id': 11094, 'Sandoval_RN': 120, 'AFT_GUID': 3518, 'card': 469, 'branch': 933, 'assessment': 1073, 'Annual_salary': 203, 'Mailing_Address': 203, 'Middle_name': 144}, 'zcsXmlV5Hv': {'ZIP': 3140, 'City': 3135, 'Unit': 3102, 'State': 3138, 'School': 2142, 'Address': 3135, 'Worksite': 3083, 'Job_Class': 1592, 'Job_Title': 3378, 'Dues_Category': 3001, 'Location_Name': 3383, 'Member_Status': 1960, 'JFT_Association': 1984, 'Years_Experince': 2089, 'custom_external_id': 1778, 'Member_ID': 1381, 'School_Board_District': 1513, 'MeetingTime_080220': 451, 'Address_2': 115, 'Assesments': 54, 'Last_Visit': 53, 'Staff': 19, 'Volunteered_Before': 2, 'Potential_Leaders': 3, 'COPE_Contributor': 0, 'Been_To_Meetings': 0}, 'ssIk7UtzyB': {'Worksite': 8300}, 'AU7HhX5W9D': {}, '9EuVaxkxTR': {'Member_ID': 1}, 'Pel07f4Ys0': {'ZIP': 0, 'City': 0, 'DWID': 0, 'State': 0, 'VAN_ID': 0, 'Address': 0, 'Employer': 0, 'Local_ID': 0, 'Job_Class': 0, 'Department': 0, 'Member_Status': 0, 'Worksite_Name': 0}, 'kNofxyoOZi': {'Member_Status': 56}, 'mNLScCAuHo': {'Dept': 0, 'FT_PT': 0, 'Campus': 0, 'MembershipStatus': 0, 'custom_external_id': 0}, 'wMIUO0cRaQ': {'tags': 93, 'Employer': 87, 'Job_Class': 50, 'Unique_ID': 91, 'Department': 50, 'Member_Status': 87, 'State_Affiliate': 91, 'Affiliate_Number': 91, 'psu_email': 37}, 'PQYfoMY5V2': {'City': 0, 'Dept': 0, 'FT_PT': 0, 'State': 0, 'Address': 0, 'Zip_Code': 0, 'Membership': 0}, 'SN5e0IFeaZ': {'Zip': 0, 'City': 0, 'State': 0, 'Address': 0, 'Worksite': 0, 'Job_Title': 0, 'Member_Status': 0}}
out = []

for k,v in res.items():
    for x,y in v.items():
        out.append({'orgid':k, 'custom_field':x, 'count':y})
    
df = pd.DataFrame(data=out)


print (df)

df.to_excel('dict1.xlsx')
# Out:
#            orgid      custom_field  count
# 0     0LjPO12b3x               ZIP  12635
# 1     0LjPO12b3x           Chapter  11025
# 2     0LjPO12b3x         Affiliate   6943
# 3     0LjPO12b3x  Leadership_Title    133
# 4     0LjPO12b3x              City   3451
# ...          ...               ...    ...
# 1913  SN5e0IFeaZ             State      0
# 1914  SN5e0IFeaZ           Address      0
# 1915  SN5e0IFeaZ          Worksite      0
# 1916  SN5e0IFeaZ         Job_Title      0
# 1917  SN5e0IFeaZ     Member_Status      0
#
# [1918 rows x 3 columns]
