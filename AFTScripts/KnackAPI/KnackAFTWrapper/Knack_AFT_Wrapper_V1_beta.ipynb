# %%
import os
import requests
import json
import pandas as pd
import urllib.parse
from pathlib import Path
from datetime import date
from datetime import timedelta


class KnackAFT:
    def __init__(self):
        # API #
        self.API_VERSION = 'v1'
        self.API_KEY = '1a210580-315e-11ea-a6a4-bb031a9e1ba1'
        self.APP_ID = '5e13989941e72c0e039e117f'
        self.CUSTOM_KNACK_ENDPOINT = 'knack.aft.org'
        
        # HTTP REQUESTS #
        self.GET_HEADERS = {'X-Knack-REST-API-KEY':self.API_KEY,'X-Knack-Application-Id':self.APP_ID}
        self.POST_HEADERS = {'X-Knack-REST-API-KEY':self.API_KEY,'X-Knack-Application-Id':self.APP_ID,'content-type':'application/json'}
        self.API_URL = f'https://api.{self.CUSTOM_KNACK_ENDPOINT}/{self.API_VERSION}/'
        self.LOADER_URL = f'https://loader.{self.CUSTOM_KNACK_ENDPOINT}/{self.API_VERSION}/applications/{self.APP_ID}'

        # INTERNAL #
        self.APP_DICT = {}

        
    # function to return key for any value
    def get_key(self, dictionary ,val):
        for key, value in dictionary.items():
            if val == value:
                return key

        return ''
    
    def loader(self):
        res = requests.get(url=self.LOADER_URL)
        objects = res.json()['application']['objects']

        for obj in objects:
            fields = {}
            name = obj['name']
            key = obj['key']

            if 'Entity-' in name:
                for item in obj['fields']:
                    fields.update({item['name']:item['key']})
                self.APP_DICT.update({name.replace('Entity-', ''):{'id':key,'fields':fields}})
    
    # GET and format json from requestURL
    def getJSON(self, url):
        r = requests.get(url = self.API_URL + url, headers = self.GET_HEADERS)
        return r.json()
    
    def getObjectJSON(self, object_name):
        return (self.getJSON('objects/' + self.APP_DICT[object_name]['id']))['object']
        
    def find_matches(self, object_name, field_name, match_val):
        field_id = self.APP_DICT[object_name]['fields'][field_name]
        object_id = self.APP_DICT[object_name]['id']
        
        match_filter = {'match':'and', 'rules':[{'field':field_id, 'operator':'is', 'value': match_val}]}
        filter_for_url = urllib.parse.quote(json.dumps(match_filter))
        request_url = "objects/" + object_id + "/records?filters=" + filter_for_url
        res = self.getJSON(request_url)
        if res["total_records"] == 0:
            return ''
        else:
            return res["records"]
            
    def convert_fields_ids2name(self, object_name, ids):
        field_dict = self.APP_DICT[object_name]['fields']
        out_dict = {}
        
        for k, v in ids.items():
            if 'field' in k:
                if 'raw' in k:
                    newk = k.replace('_raw', '')
                    key = self.get_key(field_dict, newk)
                    if key:
                        out_dict.update({(key+'_raw'):v})
                    else:
                        out_dict.update({k:v})
                else:
                    key = self.get_key(field_dict, k)
                    if key:
                        out_dict.update({key:v})
                    else:
                        out_dict.update({k:v})
            else:
                out_dict.update({k:v})
        return out_dict
    
    def convert_fields_name2ids(self, object_name, names):
        for k, v in names.items():
            if 'field' in k:
                key = self.APP_DICT[object_name]['fields']
            print(k)
            print(v)

# %%
# JSON PRINT HELPER #
def jprint(output):
    print(json.dumps(output, indent=4))


# GLOBAL VARIABLES #
YESTERDAY_DATE = (date.today() - timedelta(days = 1)).strftime("%m/%d/%Y")
ENTITY_LIST = ['LocalDues','Employer','LocalAgreement','Unit','LocalJobClass','JobTitle','WorkLocation','WorkStructure']

client = KnackAFT()
client.loader()
output = client.find_matches('LocalDues', 'mdate', '08/18/2022')

jprint(client.APP_DICT)
# if output:
#     for item in output:
#         t = client.convert_fields_ids2name('LocalDues', item)
#         jprint(t)
#         jprint(client.convert_fields_name2ids('LocalDues', t))





# LIST OF METHODS FROM CLIENT

# - CT.init()
# - CT.loader()
# - CT.getJson(url)
# - CT.getObjectJSON(name)
# - CT.find_matches(object_name, field, value)
# - CT.convert_fields_ids2name(self, object_name, ids)
# - CT.convert_fields_name2ids(self, object_name, names)




# output = C.find_matches('Unit', 'mdate', '08/11/2022')
# output = C.find_matches('Unit', 'mdate', '08/11/2022')
# output = C.find_matches('Unit', 'mdate', '08/11/2022')
# output = C.find_matches('Unit', 'mdate', '08/11/2022')


        
#pl = CLIENT.getObjectPayload('Unit')
#print(json.dumps(output, indent=4)) 
#print(json.dumps(dictout['Entity-Employer'], indent=4))
# Out:
# {
#     "StateFed": {
#         "id": "object_43",
#         "fields": {
#             "AffiliateID": "field_525",
#             "AffiliateName": "field_526",
#             "AffiliateNumber": "field_527",
#             "cdate": "field_528",
#             "mdate": "field_529",
#             "Status": "field_530",
#             "TeamMember": "field_531",
#             "AffiliateGuid": "field_532",
#             "AffiliateAbbreviatedName": "field_533",
#             "AffiliateAcronym": "field_534",
#             "AffiliateEIN": "field_535",
#             "AffiliatePerCapitaPIN": "field_536",
#             "BillHighwayGroupId": "field_537",
#             "IsChartered": "field_538",
#             "CharterDate": "field_539",
#             "ParentAffiliateId": "field_540",
#             "AffiliateTypeId": "field_541",
#             "AffiliateDesignationId": "field_542",
#             "AffiliateGeoReachId": "field_543",
#             "IsAffiliateActive": "field_544",
#             "AffiliateInactiveReasonId": "field_545",
#             "AffiliateInactiveDate": "field_546",
#             "LocationStateAbr": "field_547",
#             "RegionId": "field_548",
#             "RetireeEntityTypeId": "field_549",
#             "RetireeDestinationId": "field_550",
#             "ElectionMonth": "field_551",
#             "OfficerTermStartMonth": "field_552",
#             "IsElectionYearOdd": "field_553",
#             "ElectionTermYears": "field_554",
#             "NoNcoaUpdate": "field_555",
#             "NoNationalUpdate": "field_556",
#             "NoStateUpdate": "field_557",
#             "NoLanWanUpdate": "field_558",
#             "NoExternalUpdate": "field_559",
#             "AffiliateWebsite": "field_560",
#             "IsActionNetwork": "field_561",
#             "UsesAftMemberId": "field_562",
#             "CreatedBy": "field_563",
#             "CreatedAt": "field_564",
#             "UpdatedBy": "field_565",
#             "UpdatedAt": "field_566",
#             "DeletedAt": "field_567",
#             "LocalNum": "field_568",
#             "CountStatePerCapita": "field_872",
#             "LastProcessed": "field_936"
#         }
#     },
#     "Affiliate": {
#         "id": "object_25",
#         "fields": {
#             "AffiliateID": "field_126",
#             "AffiliateName": "field_120",
#             "AffiliateNumber": "field_127",
#             "cdate": "field_129",
#             "mdate": "field_151",
#             "Status": "field_130",
#             "TeamMember": "field_147",
#             "AffiliateGuid": "field_203",
#             "AffiliateAbbreviatedName": "field_204",
#             "AffiliateAcronym": "field_205",
#             "AffiliateEIN": "field_206",
#             "AffiliatePerCapitaPIN": "field_207",
#             "BillHighwayGroupId": "field_208",
#             "IsChartered": "field_209",
#             "CharterDate": "field_210",
#             "ParentAffiliateId": "field_211",
#             "AffiliateTypeId": "field_212",
#             "AffiliateDesignationId": "field_213",
#             "AffiliateGeoReachId": "field_214",
#             "IsAffiliateActive": "field_215",
#             "AffiliateInactiveReasonId": "field_216",
#             "AffiliateInactiveDate": "field_217",
#             "LocationStateAbr": "field_218",
#             "RegionId": "field_219",
#             "RetireeEntityTypeId": "field_220",
#             "RetireeDestinationId": "field_221",
#             "ElectionMonth": "field_222",
#             "OfficerTermStartMonth": "field_223",
#             "IsElectionYearOdd": "field_224",
#             "ElectionTermYears": "field_225",
#             "NoNcoaUpdate": "field_226",
#             "NoNationalUpdate": "field_227",
#             "NoStateUpdate": "field_228",
#             "NoLanWanUpdate": "field_229",
#             "NoExternalUpdate": "field_230",
#             "AffiliateWebsite": "field_231",
#             "IsActionNetwork": "field_232",
#             "UsesAftMemberId": "field_233",
#             "CreatedBy": "field_234",
#             "CreatedAt": "field_235",
#             "UpdatedBy": "field_236",
#             "UpdatedAt": "field_237",
#             "DeletedAt": "field_238",
#             "LocalNum": "field_468",
#             "Entity-StateFed": "field_570",
#             "IsParent": "field_577",
#             "AffiliateNumberandName": "field_744",
#             "Affiliate#andName": "field_745",
#             "DuesErrors": "field_778",
#             "C-Connect": "field_876",
#             "LastProcessed": "field_937"
#         }
#     },
#     "Chapter": {
#         "id": "object_26",
#         "fields": {
#             "ChapterID": "field_148",
#             "Entity-Affiliate": "field_132",
#             "ChapterNumber": "field_152",
#             "IsStructural": "field_149",
#             "IsChapterStructural?": "field_150",
#             "IsChapterActive": "field_153",
#             "ChapterGuid": "field_239",
#             "ChapterName": "field_240",
#             "ChapterEIN": "field_241",
#             "IsChartered": "field_242",
#             "CharterDate": "field_243",
#             "ElectionMonth": "field_244",
#             "OfficerTermStartMonth": "field_245",
#             "IsElectionYearOdd": "field_246",
#             "ElectionTermYears": "field_247",
#             "IsUnknown": "field_248",
#             "CreatedBy": "field_249",
#             "CreatedAt": "field_250",
#             "UpdatedBy": "field_251",
#             "UpdatedAt": "field_252",
#             "DeletedAt": "field_253",
#             "RunningEditsTable": "field_690",
#             "EmployerCount": "field_819",
#             "LastProcessed": "field_938"
#         }
#     },
#     "Divisions": {
#         "id": "object_17",
#         "fields": {
#             "DivisionId": "field_108",
#             "DivisionName": "field_109",
#             "DisplayOrder": "field_110",
#             "KnackDivisionRecordID": "field_135",
#             "DivisionPerCapitaName": "field_154",
#             "CreatedBy": "field_155",
#             "CreatedAt": "field_156",
#             "UpdatedBy": "field_157",
#             "UpdatedAt": "field_158",
#             "DeletedAt": "field_159"
#         }
#     },
#     "LocalDues": {
#         "id": "object_37",
#         "fields": {
#             "LocalDuesCategoryId": "field_451",
#             "KnackID": "field_870",
#             "KnackLocalDuesID": "field_871",
#             "LocalDuesCategoryName": "field_452",
#             "Entity-Affiliate": "field_448",
#             "Entity-StatePercapita": "field_449",
#             "Entity-NationalPercapita": "field_450",
#             "LocalDuesAmount": "field_453",
#             "LocalDuesPercentage": "field_454",
#             "PaymentFrequencyId": "field_455",
#             "StartDate": "field_456",
#             "EndDate": "field_457",
#             "CreatedBy": "field_458",
#             "CreatedAt": "field_459",
#             "UpdatedBy": "field_460",
#             "UpdatedAt": "field_461",
#             "DeletedAt": "field_462",
#             "mdate": "field_469",
#             "muser": "field_470",
#             "Entity-StateFed": "field_572",
#             "LocalState": "field_575",
#             "StateLocation": "field_576",
#             "DeleteLocalDues": "field_578",
#             "MoveRecordsTo": "field_579",
#             "RunningEditsTable": "field_714",
#             "RunningEditsIAIE": "field_715",
#             "AffiliateID": "field_783",
#             "NationalPerCapitaID": "field_790",
#             "StatePerCapitaID": "field_791",
#             "Action": "field_792",
#             "MoveRecordsToID": "field_793",
#             "UpdateIndividualAffiliateDuesIDTo": "field_794",
#             "IsArchived": "field_853",
#             "StatePerCapitaEligible": "field_873",
#             "StatePerCapConv": "field_875",
#             "PerCapitaError": "field_874",
#             "AddToCart": "field_925",
#             "IndividualCount": "field_929",
#             "LastProcessed": "field_947",
#             "StatePerCapitaKnackID": "field_949",
#             "MoveToRecordsKnackID": "field_950",
#             "UpdatedinAFTDB": "field_1055",
#             "StatusColumn": "field_1056"
#         }
#     },
#     "LocalDues-Staging": {
#         "id": "object_50",
#         "fields": {
#             "LocalDuesCategoryId": "field_963",
#             "KnackID": "field_964",
#             "KnackLocalDuesID": "field_965",
#             "Entity-LocalDues": "field_1004",
#             "LocalDuesCategoryName": "field_966",
#             "Entity-Affiliate": "field_967",
#             "Entity-StatePercapita": "field_968",
#             "Entity-NationalPercapita": "field_969",
#             "LocalDuesAmount": "field_970",
#             "LocalDuesPercentage": "field_971",
#             "PaymentFrequencyId": "field_972",
#             "StartDate": "field_973",
#             "EndDate": "field_974",
#             "CreatedBy": "field_975",
#             "CreatedAt": "field_976",
#             "UpdatedBy": "field_977",
#             "UpdatedAt": "field_978",
#             "DeletedAt": "field_979",
#             "mdate": "field_980",
#             "muser": "field_981",
#             "Entity-StateFed": "field_982",
#             "LocalState": "field_983",
#             "StateLocation": "field_984",
#             "DeleteLocalDues": "field_985",
#             "MoveRecordsTo": "field_986",
#             "RunningEditsTable": "field_987",
#             "RunningEditsIAIE": "field_988",
#             "AffiliateID": "field_989",
#             "NationalPerCapitaID": "field_990",
#             "StatePerCapitaID": "field_991",
#             "Action": "field_992",
#             "MoveRecordsToID": "field_993",
#             "UpdateIndividualAffiliateDuesIDTo": "field_994",
#             "IsArchived": "field_995",
#             "StatePerCapitaEligible": "field_996",
#             "StatePerCapConv": "field_997",
#             "PerCapitaError": "field_998",
#             "AddToCart": "field_999",
#             "IndividualCount": "field_1000",
#             "LastProcessed": "field_1001",
#             "StatePerCapitaKnackID": "field_1002",
#             "MoveToRecordsKnackID": "field_1003",
#             "Status": "field_1005"
#         }
#     },
#     "Employer": {
#         "id": "object_16",
#         "fields": {
#             "EmployerId": "field_263",
#             "KnackID": "field_854",
#             "EmployerKnackID": "field_855",
#             "EmployerName": "field_265",
#             "Entity-EmployerType": "field_261",
#             "Entity-ParentEmployer": "field_278",
#             "Entity-Chapter": "field_262",
#             "EmployerGuid": "field_264",
#             "Acronym": "field_266",
#             "EmployerCode": "field_267",
#             "HasPrivateSector": "field_268",
#             "Area": "field_269",
#             "WebsiteURL": "field_270",
#             "IsStructural": "field_271",
#             "IsUnknown": "field_272",
#             "CreatedBy": "field_273",
#             "CreatedAt": "field_274",
#             "UpdatedBy": "field_275",
#             "UpdatedAt": "field_276",
#             "DeletedAt": "field_277",
#             "LocalAgreementCount": "field_585",
#             "WorkLocationCount": "field_586",
#             "WorkStructureCount": "field_587",
#             "WorkLocationConversion": "field_635",
#             "LocalAgreementCountConversion": "field_634",
#             "EmployertypeIDConv": "field_609",
#             "Entity-Affiliate": "field_588",
#             "mdate": "field_592",
#             "muser": "field_593",
#             "EmployerTypeID": "field_608",
#             "DeleteEmployer": "field_632",
#             "Are you sure you want to delete this employer? ": "field_638",
#             "WorkStructureConversion": "field_636",
#             "RunningEditsTable": "field_701",
#             "RunningEditsIAIE": "field_702",
#             "Action": "field_780",
#             "EmployerTypeIDRaw": "field_815",
#             "ParentEmployerIDRaw": "field_816",
#             "ChapterID": "field_817",
#             "AffiliateID": "field_818",
#             "isArchived": "field_846",
#             "ParentEmployerKnackID": "field_935",
#             "LastProcessed": "field_939",
#             "EmployerNameDropDown": "field_1007",
#             "SelectForMulti": "field_1054",
#             "AFTDBUpdate": "field_1057",
#             "StatusColumn": "field_1058"
#         }
#     },
#     "Employer-Staging": {
#         "id": "object_51",
#         "fields": {
#             "EmployerId": "field_1009",
#             "KnackID": "field_1010",
#             "EmployerKnackID": "field_1011",
#             "EmployerName": "field_1012",
#             "Entity-EmployerType": "field_1013",
#             "Entity-ParentEmployer": "field_1014",
#             "Entity-Chapter": "field_1015",
#             "EmployerGuid": "field_1016",
#             "Acronym": "field_1017",
#             "EmployerCode": "field_1018",
#             "HasPrivateSector": "field_1019",
#             "Area": "field_1020",
#             "WebsiteURL": "field_1021",
#             "IsStructural": "field_1022",
#             "IsUnknown": "field_1023",
#             "CreatedBy": "field_1024",
#             "CreatedAt": "field_1025",
#             "UpdatedBy": "field_1026",
#             "UpdatedAt": "field_1027",
#             "DeletedAt": "field_1028",
#             "LocalAgreementCount": "field_1029",
#             "WorkLocationCount": "field_1030",
#             "WorkStructureCount": "field_1031",
#             "WorkLocationConversion": "field_1032",
#             "LocalAgreementCountConversion": "field_1033",
#             "Entity-Affiliate": "field_1034",
#             "mdate": "field_1035",
#             "muser": "field_1036",
#             "EmployerTypeID": "field_1037",
#             "DeleteEmployer": "field_1038",
#             "Are you sure you want to delete this employer? ": "field_1039",
#             "WorkStructureConversion": "field_1040",
#             "RunningEditsTable": "field_1041",
#             "RunningEditsIAIE": "field_1042",
#             "Action": "field_1043",
#             "EmployerTypeIDRaw": "field_1044",
#             "ParentEmployerIDRaw": "field_1045",
#             "ChapterID": "field_1046",
#             "AffiliateID": "field_1047",
#             "isArchived": "field_1048",
#             "ParentEmployerKnackID": "field_1049",
#             "LastProcessed": "field_1050",
#             "EmployerNameDropDown": "field_1051",
#             "EmployertypeIDConv": "field_1052",
#             "Entity-Employer": "field_1053"
#         }
#     },
#     "EmployerType": {
#         "id": "object_18",
#         "fields": {
#             "EmployerTypeId": "field_254",
#             "EmployerTypeName": "field_255",
#             "CreatedBy": "field_256",
#             "CreatedAt": "field_257",
#             "UpdatedBy": "field_258",
#             "UpdatedAt": "field_259",
#             "DeletedAt": "field_260"
#         }
#     },
#     "LocalAgreementType": {
#         "id": "object_35",
#         "fields": {
#             "LocalAgreementTypeId": "field_282",
#             "LocalAgreementTypeName": "field_283",
#             "CreatedBy": "field_284",
#             "CreatedAt": "field_285",
#             "UpdatedBy": "field_286",
#             "UpdatedAt": "field_287",
#             "DeletedAt": "field_288"
#         }
#     },
#     "LocalAgreement": {
#         "id": "object_23",
#         "fields": {
#             "LocalAgreementId": "field_291",
#             "KnackID": "field_856",
#             "KnackLocalAgreementID": "field_857",
#             "LocalAgreementName": "field_292",
#             "Entity-Employer": "field_289",
#             "Entity-LocalAgreementType": "field_290",
#             "GradeStepName": "field_293",
#             "GradeStatus": "field_294",
#             "LocalAgreementRatificationDate": "field_295",
#             "LocalAgreementEffectiveStartDate": "field_296",
#             "LocalAgreementEffectiveEndDate": "field_297",
#             "LocalAgreementExpirationDate": "field_298",
#             "FileUrl": "field_299",
#             "IsStructural": "field_300",
#             "IsUnknown": "field_301",
#             "CreatedBy": "field_302",
#             "CreatedAt": "field_303",
#             "UpdatedBy": "field_304",
#             "UpdatedAt": "field_305",
#             "DeletedAt": "field_306",
#             "Entity-Affiliate": "field_589",
#             "UnitCounts": "field_639",
#             "UnitCountsT": "field_640",
#             "DeleteLocaAgreement": "field_637",
#             "AreYouSureDelete": "field_641",
#             "RunningEditsTable": "field_703",
#             "muser": "field_724",
#             "mdate": "field_725",
#             "EmployerID": "field_811",
#             "LocalAgreementTypeID": "field_812",
#             "Action": "field_813",
#             "affiliateID": "field_814",
#             "CombinedLocalAgreementEmployer": "field_840",
#             "CombinedLocalandEmployer": "field_841",
#             "isArchived": "field_847",
#             "KnackEmployerID": "field_877",
#             "LastProcessed": "field_940",
#             "AFTDBUpdate": "field_1064"
#         }
#     },
#     "UnitType": {
#         "id": "object_36",
#         "fields": {
#             "UnitTypeId": "field_309",
#             "UnitTypeName": "field_310",
#             "CreatedBy": "field_311",
#             "CreatedAt": "field_312",
#             "UpdatedBy": "field_313",
#             "UpdatedAt": "field_314",
#             "DeletedAt": "field_315"
#         }
#     },
#     "Unit": {
#         "id": "object_22",
#         "fields": {
#             "UnitId": "field_319",
#             "KnackID": "field_858",
#             "KnackUnitID": "field_859",
#             "UnitName": "field_321",
#             "Entity-UnitType": "field_316",
#             "Entity-Division": "field_318",
#             "Entity-LocalAgreement": "field_317",
#             "UnitGuid": "field_320",
#             "IsStructural": "field_322",
#             "IsUnknown": "field_323",
#             "CreatedBy": "field_324",
#             "CreatedAt": "field_325",
#             "UpdatedBy": "field_326",
#             "UpdatedAt": "field_327",
#             "DeletedAt": "field_328",
#             "Entity-Affiliate": "field_590",
#             "JobClassCount": "field_642",
#             "JobClassCounts": "field_643",
#             "DeleteUnit": "field_644",
#             "SureToDelete": "field_645",
#             "RunningEditsTable": "field_704",
#             "muser": "field_722",
#             "mdate": "field_723",
#             "UnitandDIvision": "field_771",
#             "UnitDivisionName": "field_772",
#             "Action": "field_804",
#             "UnitTypeID": "field_805",
#             "LocalAgreementID": "field_806",
#             "DivisionID": "field_807",
#             "AffiliateID": "field_808",
#             "IsArchived": "field_848",
#             "KnackLocalAgreementID": "field_878",
#             "UnionStaff(NoDivision)": "field_928",
#             "Entity-Employer": "field_934",
#             "LastProcessed": "field_941",
#             "AFTDBUpdate": "field_1065"
#         }
#     },
#     "NationalJobClass": {
#         "id": "object_20",
#         "fields": {
#             "NationalJobClassId": "field_329",
#             "NationalJobClassGuid": "field_330",
#             "NationalJobClassName": "field_331",
#             "NationalJobClassCode": "field_332",
#             "DivisionId": "field_333",
#             "CreatedBy": "field_334",
#             "CreatedAt": "field_335",
#             "UpdatedBy": "field_336",
#             "UpdatedAt": "field_337",
#             "DeletedAt": "field_338"
#         }
#     },
#     "LocalJobClass": {
#         "id": "object_21",
#         "fields": {
#             "LocalJobClassId": "field_343",
#             "KnackID": "field_860",
#             "KnackLocalJobClassID": "field_861",
#             "LocalJobClassName": "field_345",
#             "Entity-NationalJobClass": "field_341",
#             "Entity-Unit": "field_342",
#             "LocalJobClassGuid": "field_344",
#             "LocalJobClassCode": "field_346",
#             "IsStructural": "field_347",
#             "IsUnknown": "field_348",
#             "CreatedBy": "field_349",
#             "CreatedAt": "field_350",
#             "UpdatedBy": "field_351",
#             "UpdatedAt": "field_352",
#             "DeletedAt": "field_353",
#             "Entity-Affiliate": "field_591",
#             "DuplicateAsJobTitle": "field_600",
#             "JobTitleCount": "field_646",
#             "jobtitlescount2": "field_647",
#             "DeleteLocalJobClass": "field_648",
#             "SureToDelete": "field_649",
#             "MovetoOKEQ": "field_665",
#             "movetoOK": "field_666",
#             "MoveTo": "field_650",
#             "RunningEditsTable": "field_705",
#             "RunningEditsIAIE": "field_706",
#             "muser": "field_716",
#             "mdate": "field_717",
#             "Action": "field_796",
#             "MovetoIDRaw": "field_801",
#             "NationalJobClassID": "field_802",
#             "UnitID": "field_803",
#             "AffiliateID": "field_809",
#             "IsArchived": "field_849",
#             "KnackUnitID": "field_879",
#             "IndividualCount": "field_933",
#             "LastProcessed": "field_942",
#             "AFTDBUpdate": "field_1066"
#         }
#     },
#     "JobTitle": {
#         "id": "object_24",
#         "fields": {
#             "JobTitleId": "field_355",
#             "KnackID": "field_862",
#             "KnackJobTitleID": "field_863",
#             "JobTitleName": "field_356",
#             "Entity-LocalJobClass": "field_354",
#             "CompensationId": "field_357",
#             "IsStructural": "field_358",
#             "IsUnknown": "field_359",
#             "CreatedBy": "field_360",
#             "CreatedAt": "field_361",
#             "UpdatedBy": "field_362",
#             "UpdatedAt": "field_363",
#             "DeletedAt": "field_364",
#             "Entity-Affiliate": "field_597",
#             "muser": "field_601",
#             "mdate": "field_602",
#             "DeleteJobTitle": "field_652",
#             "movetoOK": "field_663",
#             "movetoOKm": "field_664",
#             "MoveTo": "field_651",
#             "RunningEditsTable": "field_707",
#             "RunningEditsIAIE": "field_708",
#             "Error": "field_727",
#             "LocalJobClassID": "field_795",
#             "Action": "field_797",
#             "MovetoTranslate": "field_798",
#             "MoveToJobTitleID": "field_799",
#             "AffiliateID": "field_810",
#             "IsArchived": "field_850",
#             "KnackLocalJobClassID": "field_880",
#             "IndividualCount": "field_932",
#             "LastProcessed": "field_943",
#             "KnackMoveToID": "field_961",
#             "SureToDelete": "field_1059",
#             "AFTDBUpdate": "field_1067"
#         }
#     },
#     "NationalInstitutionType": {
#         "id": "object_38",
#         "fields": {
#             "NationalInstitutionTypeId": "field_377",
#             "NationalInstitutionTypeName": "field_378",
#             "Entity-EmployerType": "field_376",
#             "HasPrivateSector": "field_379",
#             "CreatedBy": "field_380",
#             "CreatedAt": "field_381",
#             "UpdatedBy": "field_382",
#             "UpdatedAt": "field_383",
#             "DeletedAt": "field_384"
#         }
#     },
#     "WorkLocationType": {
#         "id": "object_19",
#         "fields": {
#             "WorkLocationTypeId": "field_366",
#             "WorkLocationTypeName": "field_367",
#             "WorkLocationTypeTrans": "field_770",
#             "Entity-EmployerType": "field_365",
#             "EmployerType": "field_769",
#             "HierachicalOrder": "field_368",
#             "CreatedBy": "field_369",
#             "CreatedAt": "field_370",
#             "UpdatedBy": "field_371",
#             "UpdatedAt": "field_372",
#             "DeletedAt": "field_373",
#             "EmployertypeID": "field_669",
#             "EmployerTypeIDNu": "field_670",
#             "EmployerandWorkLocationType": "field_767",
#             "EmployerandWorkType": "field_768"
#         }
#     },
#     "WorkLocation": {
#         "id": "object_28",
#         "fields": {
#             "WorkLocationId": "field_389",
#             "KnackID": "field_864",
#             "KnackWorkLocationID": "field_865",
#             "WorkLocationName": "field_391",
#             "Entity-Employer": "field_385",
#             "Entity-NationalInstitutionType": "field_386",
#             "Entity-WorkLocationType": "field_387",
#             "Entity-ParentWorkLocation": "field_388",
#             "WorkLocationGuid": "field_390",
#             "WorkLocationCode": "field_392",
#             "WorkLocationArea": "field_393",
#             "IsPubliclyAccessible": "field_394",
#             "CreatedBy": "field_395",
#             "CreatedAt": "field_396",
#             "UpdatedBy": "field_397",
#             "UpdatedAt": "field_398",
#             "DeletedAt": "field_399",
#             "Entity-Affiliate": "field_598",
#             "muser": "field_603",
#             "mdate": "field_604",
#             "DeleteWorkLocation": "field_653",
#             "MoveTo": "field_654",
#             "MovetoOKEq": "field_661",
#             "movetoOK": "field_662",
#             "EmployerTypeMatch": "field_667",
#             "MatchtypevsEMpl": "field_672",
#             "RunningEditsTable": "field_709",
#             "RunningEditsIAIE": "field_710",
#             "Action": "field_820",
#             "WorkLocationTypeID": "field_821",
#             "ParentWorkLocationID": "field_822",
#             "NationalInstTypeID": "field_823",
#             "EmployerID": "field_824",
#             "AffiliateID": "field_825",
#             "MoveToID": "field_830",
#             "IsArchived": "field_851",
#             "IndividualCount": "field_931",
#             "LastProcessed": "field_944",
#             "KnackEmployerID": "field_951",
#             "MoveToKnackID": "field_953",
#             "ParentKnackID": "field_956",
#             "SureToDelete": "field_1060",
#             "AFTDBUpdate": "field_1062"
#         }
#     },
#     "WorkStructure": {
#         "id": "object_29",
#         "fields": {
#             "WorkStructureId": "field_412",
#             "KnackID": "field_866",
#             "KnackWorkStructureID": "field_867",
#             "WorkStructureName": "field_414",
#             "Entity-Employer": "field_409",
#             "Entity-WorkStructureType": "field_410",
#             "Entity-ParentWorkStructure": "field_411",
#             "WorkStructureGuid": "field_413",
#             "WorkStructureCode": "field_415",
#             "CreatedBy": "field_416",
#             "CreatedAt": "field_417",
#             "UpdatedBy": "field_418",
#             "UpdatedAt": "field_419",
#             "DeletedAt": "field_420",
#             "Entity-Affiliate": "field_599",
#             "muser": "field_605",
#             "mdate": "field_606",
#             "WorkStandEmployerMatch": "field_607",
#             "EmployerMatchOK": "field_612",
#             "WorkStructureNewName": "field_614",
#             "DeleteWorkStructure": "field_655",
#             "MovetoEq": "field_659",
#             "MovetoOK": "field_660",
#             "MoveTo": "field_656",
#             "WorkStructureType": "field_673",
#             "RunningEditsTable": "field_711",
#             "RunningEditsIAIE": "field_712",
#             "EmployerID": "field_826",
#             "WorkStructureTypeID": "field_827",
#             "ParentWorkStructureID": "field_828",
#             "Action": "field_829",
#             "IsArchived": "field_852",
#             "IndividualCount": "field_930",
#             "LastProcessed": "field_945",
#             "KnackEmployerID": "field_952",
#             "MoveToKnackID": "field_954",
#             "ParentKnackID": "field_955",
#             "SureToDelete": "field_1061",
#             "AFTDBUpdate": "field_1063"
#         }
#     },
#     "WorkStructureType": {
#         "id": "object_30",
#         "fields": {
#             "WorkStructureTypeId": "field_401",
#             "WorkStructureTypeName": "field_402",
#             "Entity-EmployerType": "field_400",
#             "HierachicalOrder": "field_403",
#             "CreatedBy": "field_404",
#             "CreatedAt": "field_405",
#             "UpdatedBy": "field_406",
#             "UpdatedAt": "field_407",
#             "DeletedAt": "field_408",
#             "EmployerType": "field_610",
#             "EmployerTypeID": "field_611",
#             "EmployerTypeandWorkStructureType": "field_613"
#         }
#     },
#     "NationalPercapita": {
#         "id": "object_40",
#         "fields": {
#             "NationalPerCapitaId": "field_425",
#             "NationalPerCapitaName": "field_426",
#             "NationalPerCapitaGuid": "field_427",
#             "NationalPerCapitaAmount": "field_428",
#             "IsAgencyFee": "field_429",
#             "DisplayOrder": "field_430",
#             "CreatedBy": "field_431",
#             "CreatedAt": "field_432",
#             "UpdatedBy": "field_433",
#             "UpdatedAt": "field_434",
#             "DeletedAt": "field_435"
#         }
#     },
#     "StatePercapita": {
#         "id": "object_39",
#         "fields": {
#             "StatePerCapitaId": "field_438",
#             "KnackID": "field_868",
#             "KnackStatePerCapitaID": "field_869",
#             "StatePerCapitaName": "field_439",
#             "StatePerCapitaAmount": "field_440",
#             "Entity-Affiliate": "field_436",
#             "Entity-NationalPercapita": "field_437",
#             "IsAgencyFee": "field_441",
#             "PaymentFrequencyId": "field_442",
#             "CreatedBy": "field_443",
#             "CreatedAt": "field_444",
#             "UpdatedBy": "field_445",
#             "UpdatedAt": "field_446",
#             "DeletedAt": "field_447",
#             "Entity-StateFed": "field_571",
#             "StateFedName": "field_573",
#             "DeleteStatePerCapita": "field_580",
#             "Moveto": "field_581",
#             "IsStatePErcapita": "field_582",
#             "MoveAllowedEqu": "field_657",
#             "movetoOK": "field_658",
#             "RunningEditsTable": "field_713",
#             "LastProcessed": "field_946"
#         }
#     }
# }

# %%
sorting_dict = {
    'LocalDuesCategory':{
        'extras_array':[False, True, False],
        'sort_array':['User','Action','KnackFieldGUID','LocalDuesCategoryID','LocalDuesCategoryName','StatePerCapitaID','NationalPerCapitaID','LocalDuesAmount','LocalDuesPercentage','CreatedAt','UpdatedAt','DeletedAt','UpdateIndividualAffiliateToID','UpdateIndividualAffiliateToName','UpdateIndividualAffiliateToKnackGUID','AffiliateID','ProcessedInAFTDB']
    },
    'Employer':{
        'extras_array':[False, False, True],
        'sort_array':['User','Action','KnackFieldGUID','EmployerID','EmployerName','EmployerTypeID','ParentEmployerID','ParentEmployerName','ParentEmployerKnackGUID','Acronym','EmployerCode','Area','ChapterID','HasPrivateSector','IsStructural','IsUnknown','CreatedAt','UpdatedAt','DeletedAt','AffiliateID','ProcessedInAFTDB']
    },
    'LocalAgreement':{
        'extras_array':[True, False, False],
        'sort_array':['User','Action','KnackFieldGUID','LocalAgreementID','LocalAgreementName','EmployerID','EmployerName','EmployerKnackGUID','LocalAgreementTypeID','IsStructural','IsUnknown','CreatedAt','UpdatedAt','DeletedAt','AffiliateID','ProcessedInAFTDB']
    },
    'Unit':{
        'extras_array':[True, False, False],
        'sort_array':['User','Action','KnackFieldGUID','UnitID','UnitName','UnitTypeID','DivisionID','LocalAgreementID','LocalAgreementName','LocalAgreementKnackGUID','IsStructural','IsUnknown','CreatedAt','UpdatedAt','DeletedAt','AffiliateID','ProcessedInAFTDB']
    },
    'LocalJobClass':{
        'extras_array':[True, True, False],
        'sort_array':['User','Action','KnackFieldGUID','LocalJobClassID','LocalJobClassName','NationaJobClassID','UnitID','UnitName','UnitKnackGUID','IsStructural','IsUnknown','CreatedAt','UpdatedAt','DeletedAt','UpdateIndividualEmployerToID','UpdateIndividualEmployerToName','UpdateIndividualEmployerToKnackGUID','AffiliateID','ProcessedInAFTDB']
    },
    'JobTitle':{
        'extras_array':[True, True, False],
        'sort_array':['User','Action','KnackFieldGUID','JobTitleID','JobTitleName','LocalJobClassID','LocalJobClassName','LocalJobClassKnackGUID','IsStructural','IsUnknown','CreatedAt','UpdatedAt','DeletedAt','UpdateIndividualEmployerToID','UpdateIndividualEmployerToName','UpdateIndividualEmployerToKnackGUID','AffiliateID','ProcessedInAFTDB']
    },
    'WorkLocation':{
        'extras_array':[True, True, True],
        'sort_array':['User','Action','KnackFieldGUID','WorkLocationID','WorkLocationName','WorkLocationTypeID','NationalInstitutionTypeID','ParentWorkLocationID','ParentWorkLocationName','ParentWorkLocationKnackGUID','EmployerID','EmployerName','EmployerKnackGUID','WorkLocationCode','WorkLocationArea','CreatedAt','UpdatedAt','DeletedAt','UpdateIndividualEmployerToID','UpdateIndividualEmployerToName','UpdateIndividualEmployerToKnackGUID','AffiliateID','ProcessedInAFTDB']
    },
    'WorkStructure':{
        'extras_array':[True, True, True],
        'sort_array':['User','Action','KnackFieldGUID','WorkStructureID','WorkStructureName','WorkStructureTypeID','ParentWorkStructureID','ParentWorkStructureName','ParentWorkStructureKnackGUID','EmployerID','EmployerName','EmployerKnackGUID','WorkStructureCode','CreatedAt','UpdatedAt','DeletedAt','UpdateIndividualEmployerToID','UpdateIndividualEmployerToName','UpdateIndividualEmployerToKnackGUID','AffiliateID','ProcessedInAFTDB']
    }
}





def find_records_updated_at_date(knack_object, date):
    #Convert to IDs
    knack_object_id = find_object_id(knack_object)
    field_to_match_id = find_field_id(knack_object, "mdate")
    
    #Get Id
    match_filter = {'match':'and', 'rules':[{'field':field_to_match_id, 'operator':'is', 'value': date}]}
    filter_for_url = urllib.parse.quote(json.dumps(match_filter))
    request_url = "https://api.knack.aft.org/v1/objects/" + knack_object_id + "/records?filters=" + filter_for_url
    
    r = requests.get(url = request_url, headers = GET_HEADERS)
    #print(json.dumps(r.json(), indent=4))
    res_json_dict = json.loads(json.dumps(r.json()))
    if res_json_dict["total_records"] == 0:
        return ''
    else:
        return res_json_dict["records"]

    
def find_connection_payload(name, lookup):
    output = {}
    knack_object_id = find_object_id(name)
    if lookup:
        request_url = "https://api.knack.aft.org/v1/objects/" + knack_object_id + "/records/" + lookup
        r = requests.get(url = request_url, headers = GET_HEADERS)
        output = json.loads(json.dumps(r.json()))
        return output
    else:
        return ''
    

def getFields(record, object_name):
    obj = knackmappingdict[object_name]
    output = {}
    
    conn_values = obj['fields']
    conn_values.update({(object_name+'ID'):obj['ID'], 'KnackFieldGUID':obj['GUID']})
    
    for k,v in conn_values.items():
        if record[v]:
            data = record[v]
        else:
            data = ''
        output.update({k:data})
        
    output['UpdatedAt'] = output.pop('mdate')
    
    if output[(object_name+'ID')]:
        if output['DeletedAt']:
            output.update({'Action':'Delete'})
        else:
            output.update({'Action':'Update'})
    else:
        if output['DeletedAt']:
            output = {}
        else:
            output.update({'Action':'Insert'})
    if output:
        output.update({'ProcessedInAFTDB':'0'})
    #print(yaml.dump(dict_out, default_flow_style=False))
    return output


def getConnections(record, object_name):
    obj = knackmappingdict[object_name]
    output = {}
    
    conn_values = obj['connections']
    
    for k,v in conn_values.items():
        fieldval = v.replace('_raw', '')
        res = ''
        knack_object = k.replace('Entity-', '')
        if record[fieldval]:
            data = record[v][0]['id']
            field_id = knackmappingdict[knack_object]['ID']
            res = find_connection_payload(knack_object, data)[field_id]
        output.update({(knack_object+'ID'):res})
        
    output['User'] = output.pop('UserID')
    return output
    

def getMappedFields(record, object_name):
    conn_values = knackmappingdict[object_name]['mapped_fields']
    for k,v in conn_values.items():
        entity = k.replace('Entity-', '')
        output = {entity+'ID':'',entity+'Name':'', entity+'KnackGUID':''}
        fieldval = v.replace('_raw', '')
        if record[v]:
            data = record[v][0]['id']
                
            field_id = knackmappingdict[entity]['ID']
            field_guid = knackmappingdict[entity]['GUID']
            field_name = knackmappingdict[entity]['fields'][(entity+'Name')]
                
            res = find_connection_payload(entity, data)
            out_id = res[field_id]
            out_guid = res[field_guid]
            out_name = res[field_name]
                
            output.update({entity+'ID':out_id,entity+'Name':out_name, entity+'KnackGUID':out_guid})
    
    #print(yaml.dump(dict_out, default_flow_style=False))
    return output


def getParent(record, object_name):
    output = {'Parent'+object_name+'ID':'','Parent'+object_name+'Name':'', 'Parent'+object_name+'KnackGUID':''}
    conn_values = knackmappingdict[object_name]['parent_fields']
    for k,v in conn_values.items():
        if 'Parent' in k:
            fieldval = v.replace('_raw', '')
            if record[fieldval]:
                data = record[v][0]['id']
                
                field_id = knackmappingdict[object_name]['ID']
                field_guid = knackmappingdict[object_name]['GUID']
                field_name = knackmappingdict[object_name]['fields'][(object_name+'Name')]
                
                res = find_connection_payload(object_name, data)
                out_id = res[field_id]
                out_guid = res[field_guid]
                out_name = res[field_name]
                
                output.update({'Parent'+object_name+'ID':out_id,'Parent'+object_name+'Name':out_name, 'Parent'+object_name+'KnackGUID':out_guid})
    
    #print(yaml.dump(dict_out, default_flow_style=False))
    return output


def getMoveTo(record, object_name):
    if object_name == 'LocalDuesCategory':
        phelper = 'Affiliate'
    else:
        phelper = 'Employer'
        
    output = {'UpdateIndividual'+phelper+'ToID':'','UpdateIndividual'+phelper+'ToName':'', 'UpdateIndividual'+phelper+'ToKnackGUID':''}
    conn_values = knackmappingdict[object_name]['move_to_fields']
    for k,v in conn_values.items():
        if 'MoveTo' in k:
            fieldval = v.replace('_raw', '')
            if record[fieldval]:
                data = record[v][0]['id']
                
                field_id = knackmappingdict[object_name]['ID']
                field_guid = knackmappingdict[object_name]['GUID']
                field_name = knackmappingdict[object_name]['fields'][(object_name+'Name')]
                
                res = find_connection_payload(object_name, data)
                out_id = res[field_id]
                out_guid = res[field_guid]
                out_name = res[field_name]
                
                output.update({'UpdateIndividual'+phelper+'ToID':out_id,'UpdateIndividual'+phelper+'ToName':out_name, 'UpdateIndividual'+phelper+'ToKnackGUID':out_guid})
    
    #print(yaml.dump(dict_out, default_flow_style=False))
    return output


def payload_runner(entity_name, mapped, moveTo, parent):
    payload = find_records_updated_at_date(entity_name, DATE_TO_RUN)
    out = []
    #print(yaml.dump(payload, default_flow_style=False))
    for record in payload:
        fields = getFields(record, entity_name)
        connections = getConnections(record, entity_name)
        output1 = {**fields, **connections}

        if (mapped):
            
            # MAPPED FIELDS
            output2 = getMappedFields(record, entity_name)
            output1 = {**output1, **output2}
        if (moveTo):
            
            # MOVE TO FIELDS
            output2 = getMoveTo(record, entity_name)
            output1 = {**output1, **output2}
        if (parent):
            
            # PARENT FIELDS
            output2 = getParent(record, entity_name)
            output1 = {**output1, **output2}
        
        if fields:
            out.append(output1)
    return pd.DataFrame(out, dtype=str) 
            
def entity_runner(entity):
    print('Running Entity: '+entity+'...')

    extras = sorting_dict[entity]['extras_array']
    sort = sorting_dict[entity]['sort_array']

    output_df = payload_runner(entity, extras[0], extras[1], extras[2])
    rows = output_df.shape[0]
    columns = output_df.shape[1]

    if rows == 0 or columns == 0:
        print('No Changes found for '+entity+'!')
        print('Skipping write to civis...')
    else:
        print('Found '+str(rows)+' rows!')

        output_df = output_df[sort]
        entity = entity.lower()
        table_name = os.environ['table_schema'] + entity

        print('Fake writing to civis table: ' + table_name + '...')
        print(output_df)
        print('Done with debug output!')

def main():
    list_to_run =['LocalDuesCategory','Employer','LocalAgreement','Unit','LocalJobClass','JobTitle','WorkLocation','WorkStructure']
    for entity in list_to_run:
        print("================================")
        entity_runner(entity)
    print("================================")

main()

# %%
pip install yaml
# Out:
# ERROR: Could not find a version that satisfies the requirement yaml (from versions: none)
# ERROR: No matching distribution found for yaml
# WARNING: You are using pip version 21.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/3.1.14_1/libexec/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
