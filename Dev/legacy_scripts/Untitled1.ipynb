# %%
import requests
  
# api-endpoint
URL = "https://sis.rutgers.edu/courses?year=2022&term=1&campus=NB"

# params dict for the parameters to be sent to the API
PARAMS = {}
  
# Get request for URL w/ params
r = requests.get(url = URL, params = PARAMS)
  
# extracting data in json format
print(r.text)
#data = tst.json()
#print(data)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#     <head>
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#         <meta charset="UTF-8" />
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#         <link rel="profile" href="http://gmpg.org/xfn/11" />
#         <link rel="pingback" href="https://eas.rutgers.edu/xmlrpc.php" />
#         <title>SIS | Enterprise Application Services</title>
# <link rel="alternate" type="application/rss+xml" title="Enterprise Application Services &raquo; Feed" href="https://eas.rutgers.edu/?feed=rss2" />
# <link rel="alternate" type="application/rss+xml" title="Enterprise Application Services &raquo; Comments Feed" href="https://eas.rutgers.edu/?feed=comments-rss2" />
# 		<script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/72x72\/","ext":".png","source":{"concatemoji":"https:\/\/eas.rutgers.edu\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.3.1"}};
# ...
